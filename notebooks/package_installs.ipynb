# %% [markdown]
# # Instructions
#
# Run the whole notebook to check install required packages and check that the package versions match up.

# %%
# Python 3.11.15 runs for Mac

from platform import python_version

print(python_version())
# Out:
# 3.11.15

# %%
pip list
# Out:
# Package                   Version
# ------------------------- -----------
# annotated-types           0.7.0
# anyio                     4.12.1
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.3.0
# attrs                     26.1.0
# babel                     2.18.0
# backports.zstd            1.3.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# blinker                   1.9.0
# Brotli                    1.2.0
# cached-property           1.5.2
# certifi                   2026.2.25
# cffi                      2.0.0
# charset-normalizer        3.4.6
# cinemagoer                2023.5.1
# click                     8.3.1
# cloudpickle               3.1.2
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# Cython                    3.2.4
# dash                      4.0.0
# dash-cytoscape            0.2.0
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# dill                      0.4.1
# et_xmlfile                2.0.0
# exceptiongroup            1.3.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# Flask                     3.1.3
# fonttools                 4.62.0
# fqdn                      1.5.1
# future                    1.0.0
# gevent                    25.9.1
# greenlet                  3.3.2
# h11                       0.16.0
# h2                        4.3.0
# hpack                     4.1.0
# httpcore                  1.0.9
# httpx                     0.28.1
# hyperframe                6.1.0
# idna                      3.11
# importlib_metadata        8.8.0
# importlib_resources       6.5.2
# interpret                 0.7.7
# interpret-core            0.7.7
# ipykernel                 7.2.0
# ipython                   9.10.0
# ipython_pygments_lexers   1.1.1
# ipywidgets                8.1.8
# isoduration               20.11.0
# itsdangerous              2.2.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# joblib                    1.5.3
# json5                     0.13.0
# jsonpointer               3.0.0
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter                   1.1.1
# jupyter_client            8.8.0
# jupyter-console           6.6.3
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.4
# jupyterlab                4.5.6
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# jupyterlab_widgets        3.0.16
# kiwisolver                1.5.0
# lark                      1.3.1
# llvmlite                  0.46.0
# lxml                      6.0.2
# MarkupSafe                3.0.3
# matplotlib                3.10.8
# matplotlib-inline         0.2.1
# missingno                 0.5.2
# mistune                   3.2.0
# multiprocess              0.70.19
# munkres                   1.1.4
# mypy_extensions           1.1.0
# narwhals                  2.18.0
# nbclient                  0.10.4
# nbconvert                 7.17.0
# nbformat                  5.10.4
# nest_asyncio              1.6.0
# notebook                  7.5.5
# notebook_shim             0.2.4
# numba                     0.64.0
# numpy                     2.4.3
# openpyxl                  3.1.5
# overrides                 7.7.0
# packaging                 26.0
# pandas                    3.0.1
# pandera                   0.30.1
# pandocfilters             1.5.0
# parso                     0.8.6
# pathos                    0.3.5
# patsy                     1.0.2
# pexpect                   4.9.0
# pillow                    11.3.0
# pip                       26.0.1
# platformdirs              4.9.4
# plotly                    5.24.0
# pmdarima                  2.0.4
# pox                       0.3.7
# ppft                      1.7.8
# progressbar2              4.5.0
# prometheus_client         0.24.1
# prompt_toolkit            3.0.52
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pyarrow                   23.0.1
# pycparser                 2.22
# pydantic                  2.12.5
# pydantic_core             2.41.5
# pygam                     0.12.0
# Pygments                  2.19.2
# pyjokes                   0.6.0
# pynytimes                 0.10.0
# pyobjc-core               12.1
# pyobjc-framework-Cocoa    12.1
# pyparsing                 3.3.2
# PySocks                   1.7.1
# python-dateutil           2.9.0.post0
# python-json-logger        2.0.7
# python-utils              3.9.1
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# requests                  2.32.5
# retrying                  1.4.2
# rfc3339_validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.30.0
# SALib                     1.5.2
# scikit-learn              1.8.0
# scipy                     1.17.1
# seaborn                   0.13.2
# Send2Trash                2.1.0
# setuptools                82.0.1
# shap                      0.51.0
# six                       1.17.0
# slicer                    0.0.8
# sniffio                   1.3.1
# soupsieve                 2.8.3
# SQLAlchemy                2.0.48
# stack_data                0.6.3
# statsmodels               0.14.6
# tenacity                  9.1.4
# terminado                 0.18.1
# threadpoolctl             3.6.0
# tinycss2                  1.4.0
# tomli                     2.4.0
# tornado                   6.5.4
# tqdm                      4.67.3
# traitlets                 5.14.3
# typeguard                 4.5.1
# typing_extensions         4.15.0
# typing_inspect            0.9.0
# typing-inspection         0.4.2
# typing_utils              0.1.0
# tzdata                    2025.3
# ucimlrepo                 0.0.7
# unicodedata2              17.0.1
# uri-template              1.3.0
# urllib3                   2.6.3
# wcwidth                   0.6.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# Werkzeug                  3.1.6
# wheel                     0.46.3
# widgetsnbextension        4.0.15
# xgboost                   2.1.4
# zipp                      3.23.0
# zope.event                6.1
# zope.interface            8.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r ../requirements.txt
# Out:
# Collecting ipykernel==7.1.0 (from -r ../requirements.txt (line 1))
#   Using cached ipykernel-7.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting setuptools==80.10.2 (from -r ../requirements.txt (line 2))
#   Using cached setuptools-80.10.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: matplotlib==3.10.8 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (3.10.8)
# Collecting numpy==1.26.4 (from -r ../requirements.txt (line 4))
#   Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# Collecting optuna==4.7.0 (from -r ../requirements.txt (line 5))
#   Using cached optuna-4.7.0-py3-none-any.whl.metadata (17 kB)
# Collecting pandas==2.1.4 (from -r ../requirements.txt (line 6))
#   Using cached pandas-2.1.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting plotly==5.15.0 (from -r ../requirements.txt (line 7))
#   Using cached plotly-5.15.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting pmdarima==2.1.1 (from -r ../requirements.txt (line 8))
#   Using cached pmdarima-2.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.5 kB)
# Collecting prophet==1.3.0 (from -r ../requirements.txt (line 9))
#   Using cached prophet-1.3.0-py3-none-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Requirement already satisfied: requests==2.32.5 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from -r ../requirements.txt (line 10)) (2.32.5)
# Requirement already satisfied: scikit-learn==1.8.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from -r ../requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: seaborn==0.13.2 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from -r ../requirements.txt (line 12)) (0.13.2)
# Requirement already satisfied: statsmodels==0.14.6 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from -r ../requirements.txt (line 13)) (0.14.6)
# Collecting torch==2.2.0 (from -r ../requirements.txt (line 14))
#   Using cached torch-2.2.0-cp311-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting torchvision==0.17.0 (from -r ../requirements.txt (line 15))
#   Using cached torchvision-0.17.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting pytorch-lightning==1.9.5 (from -r ../requirements.txt (line 16))
#   Using cached pytorch_lightning-1.9.5-py3-none-any.whl.metadata (23 kB)
# Collecting neuralprophet==0.8.0 (from -r ../requirements.txt (line 17))
#   Using cached neuralprophet-0.8.0-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: xgboost==2.1.4 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from -r ../requirements.txt (line 18)) (2.1.4)
# Requirement already satisfied: appnope>=0.1.2 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (9.10.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging>=22 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (26.0)
# Requirement already satisfied: psutil>=5.7 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ../requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r ../requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r ../requirements.txt (line 3)) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r ../requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r ../requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r ../requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r ../requirements.txt (line 3)) (2.9.0.post0)
# Collecting alembic>=1.5.0 (from optuna==4.7.0->-r ../requirements.txt (line 5))
#   Using cached alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna==4.7.0->-r ../requirements.txt (line 5))
#   Using cached colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from optuna==4.7.0->-r ../requirements.txt (line 5)) (2.0.48)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from optuna==4.7.0->-r ../requirements.txt (line 5)) (4.67.3)
# Requirement already satisfied: PyYAML in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from optuna==4.7.0->-r ../requirements.txt (line 5)) (6.0.3)
# Collecting pytz>=2020.1 (from pandas==2.1.4->-r ../requirements.txt (line 6))
#   Using cached pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from pandas==2.1.4->-r ../requirements.txt (line 6)) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from plotly==5.15.0->-r ../requirements.txt (line 7)) (9.1.4)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from pmdarima==2.1.1->-r ../requirements.txt (line 8)) (1.5.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from pmdarima==2.1.1->-r ../requirements.txt (line 8)) (3.2.4)
# Requirement already satisfied: scipy>=1.13.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from pmdarima==2.1.1->-r ../requirements.txt (line 8)) (1.17.1)
# Requirement already satisfied: urllib3 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from pmdarima==2.1.1->-r ../requirements.txt (line 8)) (2.6.3)
# Collecting cmdstanpy>=1.0.4 (from prophet==1.3.0->-r ../requirements.txt (line 9))
#   Using cached cmdstanpy-1.3.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting holidays<1,>=0.25 (from prophet==1.3.0->-r ../requirements.txt (line 9))
#   Using cached holidays-0.93-py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: importlib_resources in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from prophet==1.3.0->-r ../requirements.txt (line 9)) (6.5.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from requests==2.32.5->-r ../requirements.txt (line 10)) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from requests==2.32.5->-r ../requirements.txt (line 10)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from requests==2.32.5->-r ../requirements.txt (line 10)) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from scikit-learn==1.8.0->-r ../requirements.txt (line 11)) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from statsmodels==0.14.6->-r ../requirements.txt (line 13)) (1.0.2)
# Collecting filelock (from torch==2.2.0->-r ../requirements.txt (line 14))
#   Using cached filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from torch==2.2.0->-r ../requirements.txt (line 14)) (4.15.0)
# Collecting sympy (from torch==2.2.0->-r ../requirements.txt (line 14))
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch==2.2.0->-r ../requirements.txt (line 14))
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from torch==2.2.0->-r ../requirements.txt (line 14)) (3.1.6)
# Collecting fsspec (from torch==2.2.0->-r ../requirements.txt (line 14))
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning==1.9.5->-r ../requirements.txt (line 16))
#   Using cached torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Collecting lightning-utilities>=0.6.0.post0 (from pytorch-lightning==1.9.5->-r ../requirements.txt (line 16))
#   Using cached lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting captum>=0.6.0 (from neuralprophet==0.8.0->-r ../requirements.txt (line 17))
#   Using cached captum-0.8.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: nbformat<6.0.0,>=5.8.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from neuralprophet==0.8.0->-r ../requirements.txt (line 17)) (5.10.4)
# Collecting tensorboard<3.0.0,>=2.11.2 (from neuralprophet==0.8.0->-r ../requirements.txt (line 17))
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from nbformat<6.0.0,>=5.8.0->neuralprophet==0.8.0->-r ../requirements.txt (line 17)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from nbformat<6.0.0,>=5.8.0->neuralprophet==0.8.0->-r ../requirements.txt (line 17)) (4.26.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.10.8->-r ../requirements.txt (line 3)) (1.17.0)
# Collecting absl-py>=0.4 (from tensorboard<3.0.0,>=2.11.2->neuralprophet==0.8.0->-r ../requirements.txt (line 17))
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard<3.0.0,>=2.11.2->neuralprophet==0.8.0->-r ../requirements.txt (line 17))
#   Using cached grpcio-1.78.0-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard<3.0.0,>=2.11.2->neuralprophet==0.8.0->-r ../requirements.txt (line 17))
#   Using cached markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard<3.0.0,>=2.11.2->neuralprophet==0.8.0->-r ../requirements.txt (line 17))
#   Using cached protobuf-7.34.0-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<3.0.0,>=2.11.2->neuralprophet==0.8.0->-r ../requirements.txt (line 17))
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from tensorboard<3.0.0,>=2.11.2->neuralprophet==0.8.0->-r ../requirements.txt (line 17)) (3.1.6)
# Collecting Mako (from alembic>=1.5.0->optuna==4.7.0->-r ../requirements.txt (line 5))
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet==1.3.0->-r ../requirements.txt (line 9))
#   Using cached stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>2021.06.0->pytorch-lightning==1.9.5->-r ../requirements.txt (line 16))
#   Using cached aiohttp-3.13.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.5->-r ../requirements.txt (line 16))
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.5->-r ../requirements.txt (line 16))
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.5->-r ../requirements.txt (line 16)) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.5->-r ../requirements.txt (line 16))
#   Using cached frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.5->-r ../requirements.txt (line 16))
#   Using cached multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.5->-r ../requirements.txt (line 16))
#   Using cached propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.5->-r ../requirements.txt (line 16))
#   Using cached yarl-1.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
# Requirement already satisfied: decorator>=4.3.2 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (0.8.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.8.0->neuralprophet==0.8.0->-r ../requirements.txt (line 17)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.8.0->neuralprophet==0.8.0->-r ../requirements.txt (line 17)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.8.0->neuralprophet==0.8.0->-r ../requirements.txt (line 17)) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (4.9.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r ../requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<3.0.0,>=2.11.2->neuralprophet==0.8.0->-r ../requirements.txt (line 17)) (3.0.3)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch==2.2.0->-r ../requirements.txt (line 14))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached ipykernel-7.1.0-py3-none-any.whl (117 kB)
# Using cached setuptools-80.10.2-py3-none-any.whl (1.1 MB)
# Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Using cached optuna-4.7.0-py3-none-any.whl (413 kB)
# Using cached pandas-2.1.4-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
# Using cached plotly-5.15.0-py2.py3-none-any.whl (15.5 MB)
# Using cached pmdarima-2.1.1-cp311-cp311-macosx_11_0_arm64.whl (592 kB)
# Using cached prophet-1.3.0-py3-none-macosx_11_0_arm64.whl (12.1 MB)
# Using cached torch-2.2.0-cp311-none-macosx_11_0_arm64.whl (59.4 MB)
# Using cached torchvision-0.17.0-cp311-cp311-macosx_11_0_arm64.whl (1.6 MB)
# Using cached pytorch_lightning-1.9.5-py3-none-any.whl (829 kB)
# Using cached neuralprophet-0.8.0-py3-none-any.whl (145 kB)
# Using cached holidays-0.93-py3-none-any.whl (1.4 MB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached torchmetrics-1.9.0-py3-none-any.whl (983 kB)
# Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached alembic-1.18.4-py3-none-any.whl (263 kB)
# Using cached captum-0.8.0-py3-none-any.whl (1.4 MB)
# Using cached cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
# Using cached stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached aiohttp-3.13.3-cp311-cp311-macosx_11_0_arm64.whl (494 kB)
# Using cached multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl (44 kB)
# Using cached yarl-1.23.0-cp311-cp311-macosx_11_0_arm64.whl (85 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl (50 kB)
# Using cached grpcio-1.78.0-cp311-cp311-macosx_11_0_universal2.whl (11.8 MB)
# Using cached lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Using cached markdown-3.10.2-py3-none-any.whl (108 kB)
# Using cached propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl (47 kB)
# Using cached protobuf-7.34.0-cp310-abi3-macosx_10_9_universal2.whl (429 kB)
# Using cached pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Using cached colorlog-6.10.1-py3-none-any.whl (11 kB)
# Using cached filelock-3.25.2-py3-none-any.whl (26 kB)
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: pytz, mpmath, tensorboard-data-server, sympy, setuptools, protobuf, propcache, plotly, numpy, networkx, multidict, markdown, Mako, lightning-utilities, grpcio, fsspec, frozenlist, filelock, colorlog, aiohappyeyeballs, absl-py, yarl, torch, tensorboard, stanio, pandas, holidays, alembic, aiosignal, torchvision, torchmetrics, optuna, ipykernel, cmdstanpy, aiohttp, prophet, pmdarima, captum, pytorch-lightning, neuralprophet
#   Attempting uninstall: setuptools━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/40 [sympy]]
#     Found existing installation: setuptools 82.0.1━━━━━━━━━━━━  3/40 [sympy]
#     Uninstalling setuptools-82.0.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/40 [sympy]
#       Successfully uninstalled setuptools-82.0.1━━━━━━━━━━━━━━━━━━  4/40 [setuptools]
#   Attempting uninstall: plotly0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/40 [protobuf]s]
#     Found existing installation: plotly 5.24.0━━━━━━━━━━━━━━━━  5/40 [protobuf]
#     Uninstalling plotly-5.24.0:90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/40 [plotly]
#       Successfully uninstalled plotly-5.24.0━━━━━━━━━━━━━━━━━━━━━━  7/40 [plotly]
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/40 [plotly]
#     Found existing installation: numpy 2.4.3━━━━━━━━━━━━━━━━━━  7/40 [plotly]
#     Uninstalling numpy-2.4.3:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/40 [plotly]
#       Successfully uninstalled numpy-2.4.3━━━━━━━━━━━━━━━━━━━━  7/40 [plotly]
#   Attempting uninstall: pandas━╺━━━━━━━━━━━━━━━━ 23/40 [tensorboard]
#     Found existing installation: pandas 3.0.1m━━━━━━━━━━━━━━━━ 23/40 [tensorboard]
#     Uninstalling pandas-3.0.1:━━━╺━━━━━━━━━━━━━━ 25/40 [pandas]]
#       Successfully uninstalled pandas-3.0.1━━━━━━━━━━━━━━ 25/40 [pandas]
#   Attempting uninstall: ipykernel━━━━━━╺━━━━━━━━ 31/40 [optuna]trics]
#     Found existing installation: ipykernel 7.2.0m━━━━━━━━ 31/40 [optuna]
#     Uninstalling ipykernel-7.2.0:━━╺━━━━━━━━ 31/40 [optuna]
#       Successfully uninstalled ipykernel-7.2.090m╺━━━━━━━ 32/40 [ipykernel]
#   Attempting uninstall: pmdarima━━━━━━━━━━━╺━━━━ 35/40 [prophet]l]
#     Found existing installation: pmdarima 2.0.4m╺━━━━ 35/40 [prophet]
#     Uninstalling pmdarima-2.0.4:━━━━━━━╺━━━━ 35/40 [prophet]
#       Successfully uninstalled pmdarima-2.0.490m╺━━━━ 35/40 [prophet]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40/40 [neuralprophet]0m [pytorch-lightning]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# salib 1.5.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pygam 0.12.0 requires scipy<1.17,>=1.11.1, but you have scipy 1.17.1 which is incompatible.
# Successfully installed Mako-1.3.10 absl-py-2.4.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 alembic-1.18.4 captum-0.8.0 cmdstanpy-1.3.0 colorlog-6.10.1 filelock-3.25.2 frozenlist-1.8.0 fsspec-2026.2.0 grpcio-1.78.0 holidays-0.93 ipykernel-7.1.0 lightning-utilities-0.15.3 markdown-3.10.2 mpmath-1.3.0 multidict-6.7.1 networkx-3.6.1 neuralprophet-0.8.0 numpy-1.26.4 optuna-4.7.0 pandas-2.1.4 plotly-5.15.0 pmdarima-2.1.1 propcache-0.4.1 prophet-1.3.0 protobuf-7.34.0 pytorch-lightning-1.9.5 pytz-2026.1.post1 setuptools-80.10.2 stanio-0.5.1 sympy-1.14.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 torch-2.2.0 torchmetrics-1.9.0 torchvision-0.17.0 yarl-1.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# check that all packages can be imported
import ipykernel
import numpy
import pandas as pd
import neuralprophet
import requests 
import os
import shutil
import pathlib 
import numpy as np
import pandas as pd
import matplotlib
import datetime
import seaborn as sns
import sklearn
import itertools
import optuna
import logging
import statsmodels
import pmdarima
import plotly
import xgboost
import warnings
import prophet
import torch
# Out:
# /opt/anaconda3/envs/RSNYCEnv/lib/python3.11/site-packages/lightning_fabric/__init__.py:29: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__("pkg_resources").declare_namespace(__name__)
# Importing plotly failed. Interactive plots will not work.
# Importing plotly failed. Interactive plots will not work.

# %%
import importlib

# Path to your requirements.txt
requirements_file = "../requirements.txt"  # replace with your path

# Special cases: PyPI package name -> Python import name
special_imports = {
    "scikit-learn": "sklearn",
    "pytorch-lightning": "pytorch_lightning",
}

# Parse the requirements.txt file
expected_versions = {}
with open(requirements_file, "r") as f:
    for line in f:
        line = line.strip()
        if not line or line.startswith("#"):
            continue
        if "==" in line:
            pkg, ver = line.split("==")
            expected_versions[pkg.strip()] = ver.strip()

# Print the header with wider spacing
print(f"{'Package':<25} {'Installed':<20} {'Expected':<15} {'Match?':<8}")
print("-" * 70)

# Check each package is installed and has the correct version
for pkg, expected_version in expected_versions.items():
    import_name = special_imports.get(pkg, pkg.replace("-", "_"))  # handle hyphens automatically
    try:
        module = importlib.import_module(import_name)
        installed_version = getattr(module, "__version__", None)
        if installed_version is None:
            # fallback for unusual cases
            installed_version = getattr(module, "version", None)
        match = "Yes" if installed_version == expected_version else "No"
        print(f"{pkg:<25} {installed_version:<20} {expected_version:<15} {match:<8}")
    except ImportError:
        print(f"{pkg:<25} {'Not installed':<20} {expected_version:<15} No")
# Out:
# Package                   Installed            Expected        Match?
# ----------------------------------------------------------------------
# ipykernel                 7.2.0                7.1.0           No
# setuptools                80.10.2              80.10.2         Yes
# matplotlib                3.10.8               3.10.8          Yes
# numpy                     1.26.4               1.26.4          Yes
# optuna                    4.7.0                4.7.0           Yes
# pandas                    2.1.4                2.1.4           Yes
# plotly                    5.15.0               5.15.0          Yes
# pmdarima                  2.1.1                2.1.1           Yes
# prophet                   1.3.0                1.3.0           Yes
# requests                  2.32.5               2.32.5          Yes
# scikit-learn              1.8.0                1.8.0           Yes
# seaborn                   0.13.2               0.13.2          Yes
# statsmodels               0.14.6               0.14.6          Yes
# torch                     2.2.0                2.2.0           Yes
# torchvision               0.17.0               0.17.0          Yes
# pytorch-lightning         1.9.5                1.9.5           Yes
# neuralprophet             0.8.0                0.8.0           Yes
# xgboost                   2.1.4                2.1.4           Yes

# %%
# If one has the torch / torchvision with the same version except +cpu, then things should still work.
