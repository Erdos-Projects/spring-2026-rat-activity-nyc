# %% [markdown]
# In the previous notebook models_citywide.ipynb, we found that the Prophet and NeuralProphet models performed well in terms of forecasting rat sightings by day citywide. In this notebook, we will do some more feature engineering and hyperparameter tuning to obtain a more optimal model.
#
# Because we wish this to be reusable, we will write things for Prophet and NeuralProphet separately.

# %% [markdown]
# # Import Packages

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /opt/anaconda3/envs/erdos_ds_environment/lib/python3.12/site-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/envs/erdos_ds_environment/lib/python3.12/site-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/erdos_ds_environment/lib/python3.12/site-packages (from plotly) (26.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression

from prophet import Prophet
from pandas.tseries.holiday import USFederalHolidayCalendar
from prophet.diagnostics import cross_validation, performance_metrics
from prophet.plot import plot_cross_validation_metric
from prophet.plot import add_changepoints_to_plot
from prophet.plot import plot_plotly, plot_components_plotly
import itertools

import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

import optuna
from neuralprophet import NeuralProphet
import logging

# %% [markdown]
# # Prophet

# %% [markdown]
# ## Import the data

# %%
# this is the time series split we will work with
tscv = TimeSeriesSplit(gap=0, max_train_size=None, n_splits=26, test_size=14)


# we import the data and clean it for future use
rs = pd.read_csv('../scr/data/cleaned_rat_sightings_data/all_cleaned_rat_sightings.csv')
rs['created_date'] = pd.to_datetime(rs['created_date']) 
rs['closed_date'] = pd.to_datetime(rs['closed_date'])
rs['resolution_action_updated_date'] = pd.to_datetime(rs['resolution_action_updated_date'])
# mark cutoff dates, and also rename columns
rs = rs[rs['created_date']<'2026-03-01']
rs = rs[rs['created_date']>='2020-01-01']
rs = rs.groupby([rs['created_date'].dt.date]).size().reset_index(name='count')
rs.rename(columns={'created_date': 'ds', 'count': 'y'}, inplace=True)
# This is should be 2251 which equals the number of days from 2020-01-01 to 2026-02-28
print(len(rs)==2251)

# %% [markdown]
# ## Prepare Prophet

# %%
date_range = pd.date_range(start="2020-01-01", end="2026-02-28")

# Generate US federal holidays
calendar = USFederalHolidayCalendar()
holidays = calendar.holidays(start=date_range.min(), end=date_range.max())

federal_holidays = pd.DataFrame({
    'holiday': 'federal_us',
    'ds': pd.to_datetime(holidays),
    'lower_window': 0,
    'upper_window': 1})

holidays = federal_holidays

# %%
rs_saved = rs.copy()
df = rs.copy()

# %% [markdown]
# ## Optuna for Hyperparameter Tuning for Prophet

# %%
import logging
logging.getLogger("cmdstanpy").setLevel(logging.WARNING)

# %%
## To tune for hyperparameters, add more possible parameters to the dictionary below and add more values to it.
## So far, the I've been able to get is {'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 5}

init_days = '2054 days'
cv_period = '14 days'
forecast_horizon = '14 days'

param_grid = {  
    'changepoint_prior_scale': [0.1, 1],
    'seasonality_prior_scale': [0.1, 1, 5, 10],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here
performance = []

# Use cross validation to evaluate all parameters
for params in all_params:
    params['holidays'] = holidays
    m = Prophet(**params).fit(df)  # Fit model with given params
    df_cv = cross_validation(m, initial = init_days, period=cv_period, horizon = forecast_horizon)
    df_p = performance_metrics(df_cv, rolling_window=14)
    performance.append(df_p)
    rmses.append(df_p['rmse'].values[0])

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses

best_params = all_params[np.argmin(rmses)]

# %%
new_performance = pd.concat(performance, ignore_index=True)

# Round numeric columns for readability
numeric_cols = ["mse", "rmse", "mae", "mape", "mdape", "smape", "coverage"]
new_performance[numeric_cols] = new_performance[numeric_cols].round(4)


new_performance

# %% [markdown]
# ## Train the Model

# %%
m = Prophet(**best_params)
m.add_country_holidays(country_name='US')
m.fit(df)
future = m.make_future_dataframe(periods=14)
forecast = m.predict(future)

# %% [markdown]
# ## Plots and Evaluation of the Model

# %%
fig1 = plot_plotly(m, forecast)
fig1.show()

fig2 = plot_components_plotly(m, forecast)
fig2.show()

# %% [markdown]
# # Neural Prophet

# %%
np.NaN = np.nan


# the following packages are meant to turn off a bunch of the warnings and ERRORs that pop up while running NeuralProphet.
# the errors that do show up are not all that important and a lot is due to outdated packages.
import warnings
import logging

warnings.filterwarnings("ignore")

logging.getLogger("neuralprophet").setLevel(logging.ERROR)
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)
logging.getLogger("NP").setLevel(logging.ERROR)

# %%
rs = pd.read_csv('../scr/data/cleaned_rat_sightings_data/all_cleaned_rat_sightings.csv')
rs['created_date'] = pd.to_datetime(rs['created_date']) 
rs['closed_date'] = pd.to_datetime(rs['closed_date'])
rs['resolution_action_updated_date'] = pd.to_datetime(rs['resolution_action_updated_date'])
# mark cutoff dates, and also rename columns
rs = rs[rs['created_date']<'2026-03-01']
rs = rs[rs['created_date']>='2020-01-01']
rs = rs.groupby([rs['created_date'].dt.date]).size().reset_index(name='count')
rs.rename(columns={'created_date': 'ds', 'count': 'y'}, inplace=True)

# %%
## Add weather data.
import requests

lat, lon = 40.7831, -73.9712
start = "2020-01-01"
end   = "2026-02-28"

url = (
    "https://archive-api.open-meteo.com/v1/archive"
    f"?latitude={lat}&longitude={lon}"
    f"&start_date={start}&end_date={end}"
    "&daily=temperature_2m_max,temperature_2m_min,temperature_2m_mean,"
    "apparent_temperature_max,apparent_temperature_min,apparent_temperature_mean,"
    "precipitation_sum,snowfall_sum"
    "&timezone=America/New_York"
)

response = requests.get(url)
data = response.json()

# %%
# Suppress cmdstanpy info logs
logging.getLogger("cmdstanpy").setLevel(logging.WARNING)


regressed_features = ['apparent_temperature_max', 'apparent_temperature_min', 'snowfall_sum']


wd = wd.reset_index(drop=True).rename(columns={"time": "ds"})
wd["ds"] = pd.to_datetime(wd["ds"])
rs["ds"] = pd.to_datetime(rs["ds"])

rs = rs.merge(
    wd[['ds'] + regressed_features],
    on="ds",
    how="left"
)

tscv = TimeSeriesSplit(gap=0, max_train_size=None, n_splits=2, test_size=14)


def objective(trial):
    regressor_lags = {
        'apparent_temperature_max': trial.suggest_int('lag_temp_max', 1, 30),
        'apparent_temperature_min': trial.suggest_int('lag_temp_min', 1, 30),
        'snowfall_sum': trial.suggest_int('lag_snowfall', 1, 7),
    }
    n_lags = trial.suggest_int('n_lags', 1, 21)
    epochs = trial.suggest_int('epochs', 10, 500)
    learning_rate = trial.suggest_float('learning_rate', 0.001, 0.5, log=True)
    batch_size = trial.suggest_int('batch_size', 20, 128)
    ar_reg = trial.suggest_float('ar_reg', 0.5, 3)
    fold_rmses = []

    for i, (train_idx, test_idx) in enumerate(tscv.split(rs)):
        train = rs.iloc[train_idx].copy()
        test = rs.iloc[test_idx].copy()
        
        existing_regressors = [col for col in regressed_features if col in train.columns]
        train = train.dropna(subset=["y"] + existing_regressors)
        test = test.dropna(subset=existing_regressors)
        
        # Skip fold if too few rows
        if len(train) < 20 or len(test) < 1:
            continue
        
        model = NeuralProphet(
            yearly_seasonality=True,
            weekly_seasonality=True,
            n_lags=n_lags,
            epochs=epochs,
            ar_reg = ar_reg,
            learning_rate=learning_rate,
            batch_size=batch_size
        )
        model.add_country_holidays(country_name="US")
        for col in existing_regressors:
            model.add_lagged_regressor(col, n_lags=regressor_lags[col])
        
        model.fit(train, freq="D", progress="off")
        future = pd.concat([
            train[['ds','y'] + existing_regressors],
            test[['ds','y']].merge(wd[['ds'] + existing_regressors], on="ds", how="left")
        ])
        future = future.dropna(subset=existing_regressors)
        forecast = model.predict(future)
        
        y_pred = forecast["yhat1"].iloc[-len(test):].values
        y_true = test["y"].values
        
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        fold_rmses.append(rmse)

        intermediate_score = np.mean(fold_rmses)
        trial.report(intermediate_score, i)
        if trial.should_prune():
            raise optuna.TrialPruned()
        
    return np.mean(fold_rmses) if fold_rmses else float("inf")

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=500)  # adjust n_trials as needed



best_params = study.best_params
# Out:
# [I 2026-03-07 15:02:41,577] A new study created in memory with name: no-name-6d3b6014-049a-4b73-91bd-6e35130a737c
# Training: 0it [00:00, ?it/s]
# Predicting: 26it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 26it [00:00, ?it/s]
# [I 2026-03-07 15:03:44,464] Trial 0 finished with value: 9.602692231806106 and parameters: {'lag_temp_max': 24, 'lag_temp_min': 29, 'lag_snowfall': 5, 'n_lags': 8, 'epochs': 431, 'learning_rate': 0.09696529223200555, 'batch_size': 86, 'ar_reg': 1.778738105783598}. Best is trial 0 with value: 9.602692231806106.
# Training: 0it [00:00, ?it/s]
# Predicting: 18it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 18it [00:00, ?it/s]
[00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 74it [00:00, ?it/s]
# [I 2026-03-07 15:26:52,561] Trial 25 finished with value: 9.100110694602405 and parameters: {'lag_temp_max': 6, 'lag_temp_min': 3, 'lag_snowfall': 1, 'n_lags': 18, 'epochs': 239, 'learning_rate': 0.03710690655714767, 'batch_size': 30, 'ar_reg': 1.0978231059987118}. Best is trial 25 with value: 9.100110694602405.
# Training: 0it [00:00, ?it/s]
# Predicting: 82it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 83it [00:00, ?it/s]
# [I 2026-03-07 15:28:16,752] Trial 26 finished with value: 9.521709926443453 and parameters: {'lag_temp_max': 6, 'lag_temp_min': 5, 'lag_snowfall': 1, 'n_lags': 19, 'epochs': 243, 'learning_rate': 0.03199741999340005, 'batch_size': 27, 'ar_reg': 1.0565986627876465}. Best is trial 25 with value: 9.100110694602405.
# Training: 0it [00:00, ?it/s]
# Predicting: 39it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 39it [00:00, ?it/s]
# [I 2026-03-07 15:28:38,097] Trial 27 finished with value: 9.26426306827442 and parameters: {'lag_temp_max': 1, 'lag_temp_min': 5, 'lag_snowfall': 1, 'n_lags': 18, 'epochs': 84, 'learning_rate': 0.04391984935305625, 'batch_size': 58, 'ar_reg': 1.148549478824568}. Best is trial 25 with value: 9.100110694602405.
# Training: 0it [00:00, ?it/s]
# Predicting: 33it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 33it [00:00, ?it/s]
# [I 2026-03-07 15:28:52,078] Trial 28 finished with value: 9.420350152467957 and parameters: {'lag_temp_max': 1, 'lag_temp_min': 5, 'lag_snowfall': 1, 'n_lags': 19, 'epochs': 75, 'learning_rate': 0.04129627323325056, 'batch_size': 68, 'ar_reg': 1.264254242054809}. Best is trial 25 with value: 9.100110694602405.
# Training: 0it [00:00, ?it/s]
# Predicting: 30it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 30it [00:00, ?it/s]
# [I 2026-03-07 15:29:04,131] Trial 29 finished with value: 9.30878030095985 and parameters: {'lag_temp_max': 1, 'lag_temp_min': 5, 'lag_snowfall': 1, 'n_lags': 18, 'epochs': 66, 'learning_rate': 0.10681190281409529, 'batch_size': 76, 'ar_reg': 1.10467330555702}. Best is trial 25 with value: 9.100110694602405.
# Training: 0it [00:00, ?it/s]
# Predicting: 82it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 83it [00:00, ?it/s]
# [I 2026-03-07 15:30:06,170] Trial 30 finished with value: 9.067951407592055 and parameters: {'lag_temp_max': 4, 'lag_temp_min': 1, 'lag_snowfall': 1, 'n_lags': 21, 'epochs': 167, 'learning_rate': 0.15528598170673422, 'batch_size': 27, 'ar_reg': 1.1274173552500457}. Best is trial 30 with value: 9.067951407592055.
# Training: 0it [00:00, ?it/s]
# Predicting: 72it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 72it [00:00, ?it/s]
# [I 2026-03-07 15:31:06,331] Trial 31 finished with value: 10.723387771104946 and parameters: {'lag_temp_max': 4, 'lag_temp_min': 1, 'lag_snowfall': 1, 'n_lags': 21, 'epochs': 176, 'learning_rate': 0.14798803285462211, 'batch_size': 31, 'ar_reg': 1.199139435043849}. Best is trial 30 with value: 9.067951407592055.
# Training: 0it [00:00, ?it/s]
# Predicting: 39it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 39it [00:00, ?it/s]
# [I 2026-03-07 15:31:27,133] Trial 32 finished with value: 9.716532088160726 and parameters: {'lag_temp_max': 5, 'lag_temp_min': 4, 'lag_snowfall': 1, 'n_lags': 20, 'epochs': 91, 'learning_rate': 0.19790278938312914, 'batch_size': 57, 'ar_reg': 0.6938124902939402}. Best is trial 30 with value: 9.067951407592055.
# Training: 0it [00:00, ?it/s]
# Predicting: 105it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting:
and parameters: {'lag_temp_max': 7, 'lag_temp_min': 2, 'lag_snowfall': 1, 'n_lags': 21, 'epochs': 260, 'learning_rate': 0.17106808303402696, 'batch_size': 37, 'ar_reg': 1.236214665551633}. Best is trial 67 with value: 8.187413588738805.
# Training: 0it [00:00, ?it/s]
# Predicting: 76it [00:00, ?it/s]
# [I 2026-03-07 15:53:06,532] Trial 72 pruned.
# Training: 0it [00:00, ?it/s]
# Predicting: 96it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 97it [00:00, ?it/s]
# [I 2026-03-07 15:53:47,858] Trial 73 finished with value: 10.686600568462465 and parameters: {'lag_temp_max': 6, 'lag_temp_min': 8, 'lag_snowfall': 1, 'n_lags': 15, 'epochs': 85, 'learning_rate': 0.11667501986060495, 'batch_size': 23, 'ar_reg': 1.4537255955827135}. Best is trial 67 with value: 8.187413588738805.
# Training: 0it [00:00, ?it/s]
# Predicting: 85it [00:00, ?it/s]
# [I 2026-03-07 15:53:54,683] Trial 74 pruned.
# Training: 0it [00:00, ?it/s]
# Predicting: 67it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 67it [00:00, ?it/s]
# [I 2026-03-07 15:54:14,924] Trial 75 finished with value: 9.729118823439672 and parameters: {'lag_temp_max': 27, 'lag_temp_min': 5, 'lag_snowfall': 6, 'n_lags': 18, 'epochs': 59, 'learning_rate': 0.21538030929859825, 'batch_size': 33, 'ar_reg': 1.6416567769404455}. Best is trial 67 with value: 8.187413588738805.
# Training: 0it [00:00, ?it/s]
# Predicting: 45it [00:00, ?it/s]
# [I 2026-03-07 15:54:47,115] Trial 76 pruned.
# Training: 0it [00:00, ?it/s]
# Predicting: 58it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 59it [00:00, ?it/s]
# [I 2026-03-07 15:54:51,630] Trial 77 finished with value: 8.75423926830229 and parameters: {'lag_temp_max': 8, 'lag_temp_min': 1, 'lag_snowfall': 2, 'n_lags': 21, 'epochs': 14, 'learning_rate': 0.18154581419047572, 'batch_size': 38, 'ar_reg': 1.905102487204111}. Best is trial 67 with value: 8.187413588738805.
# Training: 0it [00:00, ?it/s]
# Predicting: 74it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 74it [00:00, ?it/s]
# [I 2026-03-07 15:54:58,542] Trial 78 finished with value: 10.745326884633851 and parameters: {'lag_temp_max': 10, 'lag_temp_min': 1, 'lag_snowfall': 2, 'n_lags': 21, 'epochs': 14, 'learning_rate': 0.17938895687213033, 'batch_size': 30, 'ar_reg': 1.9144852654657878}. Best is trial 67 with value: 8.187413588738805.
# Training: 0it [00:00, ?it/s]
# Predicting: 53it [00:00, ?it/s]
# [I 2026-03-07 15:55:05,612] Trial 79 pruned.
# Training: 0it [00:00, ?it/s]
# Predicting: 92it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 93it [00:00, ?it/s]
# [I 2026-03-07 15:55:37,286] Trial 80 finished with value: 10.338726386696827 and parameters: {'lag_temp_max': 7, 'lag_temp_min': 28, 'lag_snowfall': 3, 'n_lags': 21, 'epochs': 75, 'learning_rate': 0.2695168736446875, 'batch_size': 24, 'ar_reg': 1.820548392956959}. Best is trial 67 with value: 8.187413588738805.
# Training: 0it [00:00, ?it/s]
# Predicting: 62it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 62it [00:00, ?it/s]
# [I 2026-03-07 15:55:46,420] Trial 81 finished with value: 9.173450960698187 and parameters: {'lag_temp_max': 6, 'lag_temp_min': 2, 'lag_snowfall': 1, 'n_lags': 20, 'epochs': 25, 'learning_rate': 0.13085026557147098, 'batch_size': 36, 'ar_reg': 2.234762615281203}. Best is trial 67 with value: 8.187413588738805.
# Training: 0it [00:00, ?it/s]
# Predicting: 36it [00:00, ?it/s]
# [I 2026-03-07 15:55:47,845] Trial 82 pruned.
# Training: 0it [00:00, ?it/s]
# Predicting: 59it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 59it [00:00, ?it/s]
# [I 2026-03-07 15:56:17,841] Trial 83 finished with value: 9.799219265591123 and parameters: {'lag_temp_max': 4, 'lag_temp_min': 6, 'lag_snowfall': 2, 'n_lags': 17, 'epochs': 117, 'learning_rate': 0.39133410278871605, 'batch_size': 38, 'ar_reg': 1.8815101115355022}. Best is trial 67 with value: 8.187413588738805.
# Training: 0it [00:00, ?it/s]
# Predicting: 32it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 32it [00:00, ?it/s]
# [I 2026-03-07 15:56:29,361] Trial 84 finished with value: 9.357815447079723 and parameters: {'lag_temp_max': 3, 'lag_temp_min': 2, 'lag_snowfall': 1, 'n_lags': 19, 'epochs': 58, 'learning_rate': 0.16497111105900847, 'batch_size': 71, 'ar_reg': 1.2251999347990532}. Best is trial 67 with value: 8.187413588738805.
# Training: 0it [00:00, ?it/s]
# Predicting: 67it [00:00, ?it/s]
# [I 2026-03-07 15:57:00,613] Trial 85 pruned.
# Training: 0it [00:00, ?it/s]
# Predicting: 82it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 83it [00:00, ?it/s]
# [I 2026-03-07 15:57:16,141] Trial 86 finished with value: 9.124395007907001 and parameters: {'lag_temp_max': 5, 'lag_temp_min': 3, 'lag_snowfall': 2, 'n_lags': 18, 'epochs': 39, 'learning_rate': 0.18896188708359846, 'batch_size': 27, 'ar_reg': 2.7703037764601097}. Best is trial 67 with value: 8.187413588738805.
# Training: 0it [00:00, ?it/s]
# Predicting: 23it [00:00, ?it/s]
and parameters: {'lag_temp_max': 12, 'lag_temp_min': 1, 'lag_snowfall': 1, 'n_lags': 15, 'epochs': 10, 'learning_rate': 0.39850497193936624, 'batch_size': 40, 'ar_reg': 1.5822674178790748}. Best is trial 111 with value: 7.993127002415202.
# Training: 0it [00:00, ?it/s]
# Predicting: 64it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 64it [00:00, ?it/s]
# [I 2026-03-07 16:16:32,719] Trial 182 finished with value: 10.476686491562171 and parameters: {'lag_temp_max': 12, 'lag_temp_min': 1, 'lag_snowfall': 1, 'n_lags': 15, 'epochs': 10, 'learning_rate': 0.41499990946803333, 'batch_size': 35, 'ar_reg': 1.553539230416989}. Best is trial 111 with value: 7.993127002415202.
# Training: 0it [00:00, ?it/s]
# Predicting: 54it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 55it [00:00, ?it/s]
# [I 2026-03-07 16:16:39,631] Trial 183 finished with value: 8.889675667280681 and parameters: {'lag_temp_max': 13, 'lag_temp_min': 1, 'lag_snowfall': 1, 'n_lags': 15, 'epochs': 19, 'learning_rate': 0.30540225059897774, 'batch_size': 41, 'ar_reg': 1.7532279906583494}. Best is trial 111 with value: 7.993127002415202.
# Training: 0it [00:00, ?it/s]
# Predicting: 50it [00:00, ?it/s]
# [I 2026-03-07 16:16:42,772] Trial 184 pruned.
# Training: 0it [00:00, ?it/s]
# Predicting: 56it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 56it [00:00, ?it/s]
# [I 2026-03-07 16:16:46,971] Trial 185 finished with value: 8.074273152211406 and parameters: {'lag_temp_max': 13, 'lag_temp_min': 1, 'lag_snowfall': 1, 'n_lags': 15, 'epochs': 10, 'learning_rate': 0.29508861918558665, 'batch_size': 40, 'ar_reg': 1.4117718496407523}. Best is trial 111 with value: 7.993127002415202.
# Training: 0it [00:00, ?it/s]
# Predicting: 56it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 56it [00:00, ?it/s]
# [I 2026-03-07 16:16:52,612] Trial 186 finished with value: 15.29491767949464 and parameters: {'lag_temp_max': 12, 'lag_temp_min': 18, 'lag_snowfall': 1, 'n_lags': 16, 'epochs': 18, 'learning_rate': 0.499939285928817, 'batch_size': 40, 'ar_reg': 1.3848895206131224}. Best is trial 111 with value: 7.993127002415202.
# Training: 0it [00:00, ?it/s]
# Predicting: 57it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 57it [00:00, ?it/s]
# [I 2026-03-07 16:17:02,752] Trial 187 finished with value: 9.120130243481078 and parameters: {'lag_temp_max': 13, 'lag_temp_min': 3, 'lag_snowfall': 1, 'n_lags': 15, 'epochs': 27, 'learning_rate': 0.292046720155657, 'batch_size': 39, 'ar_reg': 1.4321264762935029}. Best is trial 111 with value: 7.993127002415202.
# Training: 0it [00:00, ?it/s]
# Predicting: 20it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 21it [00:00, ?it/s]
# [I 2026-03-07 16:17:05,805] Trial 188 finished with value: 8.181455312058931 and parameters: {'lag_temp_max': 13, 'lag_temp_min': 4, 'lag_snowfall': 1, 'n_lags': 14, 'epochs': 16, 'learning_rate': 0.2650581682541484, 'batch_size': 111, 'ar_reg': 1.508308634728008}. Best is trial 111 with value: 7.993127002415202.
# Training: 0it [00:00, ?it/s]
# Predicting: 21it [00:00, ?it/s]
# [I 2026-03-07 16:17:07,115] Trial 189 pruned.
# Training: 0it [00:00, ?it/s]
# Predicting: 38it [00:00, ?it/s]
# [I 2026-03-07 16:17:56,048] Trial 190 pruned.
# Training: 0it [00:00, ?it/s]
# Predicting: 25it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 9it [00:00, ?it/s]
# [I 2026-03-07 16:18:10,231] Trial 191 finished with value: 38.57202486653698 and parameters: {'lag_temp_max': 13, 'lag_temp_min': 2, 'lag_snowfall': 1, 'n_lags': 14, 'epochs': 23, 'learning_rate': 0.28881395514214814, 'batch_size': 91, 'ar_reg': 1.5854533786030651}. Best is trial 111 with value: 7.993127002415202.
# Training: 0it [00:00, ?it/s]
# Predicting: 60it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 61it [00:00, ?it/s]
# [I 2026-03-07 16:18:33,605] Trial 192 finished with value: 8.575183680091305 and parameters: {'lag_temp_max': 13, 'lag_temp_min': 1, 'lag_snowfall': 1, 'n_lags': 15, 'epochs': 17, 'learning_rate': 0.32237624688243943, 'batch_size': 37, 'ar_reg': 1.4135471018618087}. Best is trial 111 with value: 7.993127002415202.
# Training: 0it [00:00, ?it/s]
# Predicting: 62it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 62it [00:00, ?it/s]
# [I 2026-03-07 16:18:47,696] Trial 193 finished with value: 8.61404364018384 and parameters: {'lag_temp_max': 12, 'lag_temp_min': 2, 'lag_snowfall': 1, 'n_lags': 14, 'epochs': 10, 'learning_rate': 0.266474655159488, 'batch_size': 36, 'ar_reg': 1.4310582027411156}. Best is trial 111 with value: 7.993127002415202.
# Training: 0it [00:00, ?it/s]
# Predicting: 29it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]

# %%
print("Best Parameters", best_params)
print("Best RMSE:", study.best_value)
# Out:
# Best Parameters {'lag_temp_max': 24, 'lag_temp_min': 8, 'lag_snowfall': 2, 'n_lags': 16, 'epochs': 140, 'learning_rate': 0.021661494826129786, 'batch_size': 105, 'ar_reg': 1.5838628383100513}
# Best RMSE: 8.633869243394198

# %%
rs = pd.read_csv('../scr/data/cleaned_rat_sightings_data/all_cleaned_rat_sightings.csv')
rs['created_date'] = pd.to_datetime(rs['created_date']) 
rs['closed_date'] = pd.to_datetime(rs['closed_date'])
rs['resolution_action_updated_date'] = pd.to_datetime(rs['resolution_action_updated_date'])
# mark cutoff dates, and also rename columns
rs = rs[rs['created_date']<'2026-03-01']
rs = rs[rs['created_date']>='2020-01-01']
rs = rs.groupby([rs['created_date'].dt.date]).size().reset_index(name='count')
rs.rename(columns={'created_date': 'ds', 'count': 'y'}, inplace=True)

## Add weather data.
import requests

lat, lon = 40.7831, -73.9712
start = "2020-01-01"
end   = "2026-02-28"

url = (
    "https://archive-api.open-meteo.com/v1/archive"
    f"?latitude={lat}&longitude={lon}"
    f"&start_date={start}&end_date={end}"
    "&daily=temperature_2m_max,temperature_2m_min,temperature_2m_mean,"
    "apparent_temperature_max,apparent_temperature_min,apparent_temperature_mean,"
    "precipitation_sum,snowfall_sum"
    "&timezone=America/New_York"
)

response = requests.get(url)
data = response.json()

# %%
tscv = TimeSeriesSplit(gap=0, max_train_size=None, n_splits=26, test_size=14)

regressed_features = ['apparent_temperature_max', 'apparent_temperature_min','snowfall_sum']


wd = wd.reset_index(drop=True).rename(columns={"time": "ds"})
wd["ds"] = pd.to_datetime(wd["ds"])
rs["ds"] = pd.to_datetime(rs["ds"])

rs = rs.merge(
    wd[['ds'] + regressed_features],
    on="ds",
    how="left"
)

lags_for_regressed_features = dict()
lags_for_regressed_features['apparent_temperature_max'] = best_params['lag_temp_max']
lags_for_regressed_features['apparent_temperature_min'] = best_params['lag_temp_min']
lags_for_regressed_features['snowfall_sum'] = best_params['lag_snowfall']


results = []

for i, (train_index, test_index) in enumerate(tscv.split(rs)):

    train = rs.iloc[train_index].copy()
    train = train.dropna(subset=["y"])

    test = rs.iloc[test_index].copy()


    model = NeuralProphet(yearly_seasonality=True, 
                          weekly_seasonality=True, 
                          learning_rate = best_params['learning_rate'],
                          epochs = best_params['epochs'],
                          n_lags= best_params['n_lags'],
                          ar_reg=best_params['ar_reg'],
                          batch_size= best_params['batch_size']
                          )
    model = model.add_country_holidays(country_name="US")
    for column in regressed_features:
        model.add_lagged_regressor(column, n_lags=lags_for_regressed_features[column])
        
    model.fit(train, freq="D", progress="off")

    # build dataframe containing future regressors
    future = pd.concat([train[['ds','y'] + regressed_features], test[['ds','y']].merge(wd[['ds'] + regressed_features], on="ds", how="left")])
    forecast = model.predict(future)

    y_pred = forecast["yhat1"].iloc[-len(test):].values
    y_true = test["y"].values

    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred)

    results.append({"fold": i, "rmse": rmse, "mape": mape})

neural_prophet_results_df = pd.DataFrame(results)
neural_prophet_results_df.loc["mean"] = ["mean", neural_prophet_results_df["rmse"].mean(), neural_prophet_results_df["mape"].mean()]
neural_prophet_results_df
# Out:
# Training: 0it [00:00, ?it/s]
# Predicting: 18it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 18it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 19it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 19it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 19it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 19it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 19it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 19it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 19it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 19it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 20it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 20it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 20it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 20it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 20it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 20it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 20it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 21it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 21it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 21it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 21it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 21it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 21it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 21it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 21it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 22it [00:00, ?it/s]
#       fold       rmse      mape
# 0        0  12.439566  0.212298
# 1        1   8.416763  0.118940
# 2        2   9.589858  0.156816
# 3        3  11.069040  0.159259
# 4        4  11.810195  0.154366
# 5        5  10.261256  0.119203
# 6        6  14.621071  0.169612
# 7        7  13.964573  0.174660
# 8        8  11.908069  0.149796
# 9        9   8.518855  0.096734
# 10      10  11.372114  0.156104
# 11      11  11.275129  0.153017
# 12      12  14.291005  0.150057
# 13      13  11.745835  0.134295
# 14      14  14.584973  0.265458
# 15      15   7.133678  0.111485
# 16      16  10.699972  0.207824
# 17      17   9.478863  0.327161
# 18      18   8.450029  0.175566
# 19      19  10.820947  0.278281
# 20      20  10.386222  0.372012
# 21      21   6.953265  0.314017
# 22      22   9.356740  0.240366
# 23      23   7.813362  0.405998
# 24      24   7.954328  0.308820
# 25      25  10.978400  0.372900
# mean  mean  10.611312  0.210963

# %%
model = NeuralProphet(yearly_seasonality=True, 
                          weekly_seasonality=True, 
                          # batch_size = best_params['batch_size'],
                          ar_reg=best_params['ar_reg'],
                          learning_rate = best_params['learning_rate'],
                          epochs = best_params['epochs'],
                          n_lags= best_params['n_lags']
                          )
model = model.add_country_holidays(country_name="US")
for column in regressed_features:
    model.add_lagged_regressor(column, n_lags=lags_for_regressed_features[column])
        
model.fit(rs, freq="D", progress="off")

new_rs = rs.copy()

new_rs = new_rs.drop(columns=['y'])

forecast = model.predict(rs)
# Out:
# Training: 0it [00:00, ?it/s]
# Predicting: 35it [00:00, ?it/s]

# %%
model.plot(forecast)
# Out:
# ERROR - (NP.plotly.plot) - plotly-resampler is not installed. Please install it to use the resampler.
