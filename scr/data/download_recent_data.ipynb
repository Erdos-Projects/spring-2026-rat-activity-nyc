# %% [markdown]
# # Download Recent Data from Open Data NYC
#
# The following Jupyter notebook downloads data from [Open Data NYC](https://opendata.cityofnewyork.us/).
#
# The data set of most importance to us is the [NYC Open Data Rat Sightings](#https://data.cityofnewyork.us/Social-Services/Rat-Sightings/3q43-55fe/about_data).

# %%
import requests 
import os
import shutil
from pathlib import Path
import pandas as pd

# %%
# We downloads the rat sightings (2020 to present) data to a folder.

import requests

url = "https://data.cityofnewyork.us/api/views/3q43-55fe/rows.csv?accessType=DOWNLOAD"

response = requests.get(url)
response.raise_for_status()

with open("rat_sightings_data/Rat_Sightings_NYC.csv", "wb") as f:
    f.write(response.content)

# %%
# Download NYC 311 data where Descriptor = "Rat Sighting"
# Split into files by year ranges with pagination. The years range from 2010-2019.
# This takes a while to run and only needs to be downloaded once, so uncomment and run if needing an update.

import os
import requests

output_folder = "rat_sightings_data"
os.makedirs(output_folder, exist_ok=True)

base_url = "https://data.cityofnewyork.us/resource/76ig-c548.csv"

ranges = [
    ("2010-01-01", "2012-12-31", "Rat_Sightings_NYC_2010_2012.csv"),
    ("2013-01-01", "2015-12-31", "Rat_Sightings_NYC_2013_2015.csv"),
    ("2016-01-01", "2017-12-31", "Rat_Sightings_NYC_2016_2017.csv"),
    ("2018-01-01", "2019-12-31", "Rat_Sightings_NYC_2018_2019.csv"),
]

LIMIT = 50000 

for start, end, filename in ranges:

    filepath = os.path.join(output_folder, filename)
    offset = 0
    first_chunk = True

    while True:

        query = (
            f"?$where=descriptor='Rat Sighting' "
            f"AND created_date between '{start}T00:00:00' and '{end}T23:59:59'"
            f"&$limit={LIMIT}&$offset={offset}"
        )

        url = base_url + query
        response = requests.get(url)
        response.raise_for_status()

        data = response.text
        lines = data.splitlines()

        if len(lines) <= 1:
            break

        with open(filepath, "a", encoding="utf-8") as f:
            if first_chunk:
                f.write(data + "\n")
                first_chunk = False
            else:
                f.write("\n".join(lines[1:]) + "\n")

        offset += LIMIT
        print(f"{filename}: downloaded {offset} rows so far")

    print(f"Finished {filename}")
# Out:
# Rat_Sightings_NYC_2010_2012.csv: downloaded 50000 rows so far
# Finished Rat_Sightings_NYC_2010_2012.csv
# Rat_Sightings_NYC_2013_2015.csv: downloaded 50000 rows so far
# Finished Rat_Sightings_NYC_2013_2015.csv
# Rat_Sightings_NYC_2016_2017.csv: downloaded 50000 rows so far
# Finished Rat_Sightings_NYC_2016_2017.csv
# Rat_Sightings_NYC_2018_2019.csv: downloaded 50000 rows so far
# Finished Rat_Sightings_NYC_2018_2019.csv

# %%
# We downloads the rat inspection data to the folder.
# We make sure to split it up so that our files are not too large.
# This takes a while to run so run it only if necessary.


out_dir = Path("split_up_rat_inspection_data")

if out_dir.exists():
    shutil.rmtree(out_dir)

out_dir.mkdir(parents=True, exist_ok=True)

URL = "https://data.cityofnewyork.us/api/views/p937-wjvj/rows.csv?accessType=DOWNLOAD"
OUT_DIR = "split_up_rat_inspection_data"
MAX_BYTES = 15 * 1024 * 1024  # 15 MB

os.makedirs(OUT_DIR, exist_ok=True)

with requests.get(URL, stream=True) as r:
    r.raise_for_status()
    lines = r.iter_lines(decode_unicode=True)

    header = next(lines) + "\n"

    part = 1
    size = 0
    f = open(f"{OUT_DIR}/rodent_inspection_{part}.csv", "w", encoding="utf-8")
    f.write(header)
    size += len(header.encode())

    for line in lines:
        line = line + "\n"
        line_bytes = len(line.encode())

        if size + line_bytes > MAX_BYTES:
            f.close()
            part += 1
            size = len(header.encode())
            f = open(f"{OUT_DIR}/rodent_inspection_{part}.csv", "w", encoding="utf-8")
            f.write(header)

        f.write(line)
        size += line_bytes

    f.close()

# %%
# We download the catch basin data to a folder.
# Uncomment and run only if needed.

import requests

url = "https://data.cityofnewyork.us/api/views/2w2g-fk3i/rows.csv?accessType=DOWNLOAD"

response = requests.get(url)
response.raise_for_status()

with open("storm_catch_basin_data/NYC_catch_basin_citywide.csv", "wb") as f:
    f.write(response.content)

# %%
# This collects NYC daily trash and refusal data.
# Uncomment and run only if data is needed.

import requests
import os

# Full CSV download URL for the DSNY Monthly Tonnage dataset
url = "https://data.cityofnewyork.us/api/views/ebb7-mvp5/rows.csv?accessType=DOWNLOAD"

# Ensure folder exists
os.makedirs("trash_data", exist_ok=True)

# Download and save
with requests.get(url, stream=True) as r:
    r.raise_for_status()
    with open("trash_data/NYC_DSNY_monthly_tonnage_2020-2026.csv", "wb") as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)

# %%
## Add weather data.
import requests


lat, lon = 40.7831, -73.9712
start = "2020-01-01"
end   = "2025-02-28"

url = (
    "https://archive-api.open-meteo.com/v1/archive"
    f"?latitude={lat}&longitude={lon}"
    f"&start_date={start}&end_date={end}"
    "&daily=temperature_2m_max,temperature_2m_min,temperature_2m_mean,"
    "apparent_temperature_max,apparent_temperature_min,apparent_temperature_mean,"
    "precipitation_sum,snowfall_sum"
    "&timezone=America/New_York"
)

response = requests.get(url)
data = response.json()


# Extract daily data
daily_data = data['daily']

# Convert to DataFrame
df = pd.DataFrame(daily_data)

# Save to CSV
df.to_csv("weather_data/wd_2020_to_march_2025.csv", index=False)

# %%
## Add weather data.
import requests


lat, lon = 40.7831, -73.9712
start = "2020-01-01"
end   = "2026-02-28"

url = (
    "https://archive-api.open-meteo.com/v1/archive"
    f"?latitude={lat}&longitude={lon}"
    f"&start_date={start}&end_date={end}"
    "&daily=temperature_2m_max,temperature_2m_min,temperature_2m_mean,"
    "apparent_temperature_max,apparent_temperature_min,apparent_temperature_mean,"
    "precipitation_sum,snowfall_sum"
    "&timezone=America/New_York"
)

response = requests.get(url)
data = response.json()


# Extract daily data
daily_data = data['daily']

# Convert to DataFrame
df = pd.DataFrame(daily_data)

# Save to CSV
df.to_csv("weather_data/wd_2020_to_march_2026.csv", index=False)
