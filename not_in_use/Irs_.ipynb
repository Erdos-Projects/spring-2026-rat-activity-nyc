# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

# %%
pd.set_option("display.max_columns", None)
sns.set_style("whitegrid")

# %%
#LOAD & COMBINE ALL EXCEL FILES (2011–2022)
folder_path = r"../../IRS folder"

files = glob.glob(os.path.join(folder_path, "*.xlsx"))
df_list = []

for file in files:
    df = pd.read_excel(file)
    df_list.append(df)

# %%
 # Extract zip code, size of adjusted gross income, adjusted gross income from filename 
filename = os.path.basename("../../IRS folder")
parts = filename.split("_")
if len(parts) >= 3:
        zip_code = parts[0]
        size_of_ag_income = parts[1]
        ag_income = parts[2].split(".")[0]  # Remove file extension
        df["Zip Code"] = zip_code
        df["Size of AGI"] = size_of_ag_income
        df["AGI"] = ag_income

# %%
# Combine all files
df = pd.concat(df_list, ignore_index=True)

print("Combined Dataset Shape:", df.shape)
# Out:
# Combined Dataset Shape: (73922, 165)

# %%
#DATA CLEANING
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("-", "_")
)

# Remove duplicates
df = df.drop_duplicates()

# Missing values summary
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# new_york           11
# unnamed:_1       9307
# unnamed:_2         89
# unnamed:_3         89
# unnamed:_4         89
#                 ...
# unnamed:_160    31773
# unnamed:_161    31770
# unnamed:_162    31773
# unnamed:_163    52921
# unnamed:_164    52922
# Length: 165, dtype: int64

# %%
 #Adjust these mappings if needed
column_map = {
    "returns": [col for col in df.columns if "return" in col],
    "exemptions": [col for col in df.columns if "exemption" in col],
    "agi": [col for col in df.columns if "adjusted_gross_income" in col or "agi" in col],
    "wages": [col for col in df.columns if "wage" in col],
    "dividends": [col for col in df.columns if "dividend" in col],
    "interest": [col for col in df.columns if "interest" in col]
    }

print("\nDetected columns:")
for k, v in column_map.items():
    print(k, ":", v)
# Out:
# Detected columns:
# returns : []
# exemptions : []
# agi : []
# wages : []
# dividends : []
# interest : []

# %%
print(df.columns.tolist())
# Out:
# ['new_york', 'unnamed:_1', 'unnamed:_2', 'unnamed:_3', 'unnamed:_4', 'unnamed:_5', 'unnamed:_6', 'unnamed:_7', 'unnamed:_8', 'unnamed:_9', 'unnamed:_10', 'unnamed:_11', 'unnamed:_12', 'unnamed:_13', 'unnamed:_14', 'unnamed:_15', 'unnamed:_16', 'unnamed:_17', 'unnamed:_18', 'unnamed:_19', 'unnamed:_20', 'unnamed:_21', 'unnamed:_22', 'unnamed:_23', 'unnamed:_24', 'unnamed:_25', 'unnamed:_26', 'unnamed:_27', 'unnamed:_28', 'unnamed:_29', 'unnamed:_30', 'unnamed:_31', 'unnamed:_32', 'unnamed:_33', 'unnamed:_34', 'unnamed:_35', 'unnamed:_36', 'unnamed:_37', 'unnamed:_38', 'unnamed:_39', 'unnamed:_40', 'unnamed:_41', 'unnamed:_42', 'unnamed:_43', 'unnamed:_44', 'unnamed:_45', 'unnamed:_46', 'unnamed:_47', 'unnamed:_48', 'unnamed:_49', 'unnamed:_50', 'unnamed:_51', 'unnamed:_52', 'unnamed:_53', 'unnamed:_54', 'unnamed:_55', 'unnamed:_56', 'unnamed:_57', 'unnamed:_58', 'unnamed:_59', 'unnamed:_60', 'unnamed:_61', 'unnamed:_62', 'unnamed:_63', 'unnamed:_64', 'unnamed:_65', 'unnamed:_66', 'unnamed:_67', 'unnamed:_68', 'unnamed:_69', 'unnamed:_70', 'unnamed:_71', 'unnamed:_72', 'unnamed:_73', 'unnamed:_74', 'unnamed:_75', 'unnamed:_76', 'unnamed:_77', 'unnamed:_78', 'unnamed:_79', 'unnamed:_80', 'unnamed:_81', 'unnamed:_82', 'unnamed:_83', 'unnamed:_84', 'unnamed:_85', 'unnamed:_86', 'unnamed:_87', 'unnamed:_88', 'unnamed:_89', 'unnamed:_90', 'unnamed:_91', 'unnamed:_92', 'unnamed:_93', 'unnamed:_94', 'unnamed:_95', 'unnamed:_96', 'unnamed:_97', 'unnamed:_98', 'unnamed:_99', 'unnamed:_100', 'unnamed:_101', 'unnamed:_102', 'unnamed:_103', 'unnamed:_104', 'unnamed:_105', 'unnamed:_106', 'unnamed:_107', 'unnamed:_108', 'unnamed:_109', 'unnamed:_110', 'unnamed:_111', 'unnamed:_112', 'unnamed:_113', 'unnamed:_114', 'unnamed:_115', 'unnamed:_116', 'unnamed:_117', 'unnamed:_118', 'unnamed:_119', 'unnamed:_120', 'unnamed:_121', 'unnamed:_122', 'unnamed:_123', 'unnamed:_124', 'unnamed:_125', 'unnamed:_126', 'unnamed:_127', 'unnamed:_128', 'unnamed:_129', 'unnamed:_130', 'unnamed:_131', 'unnamed:_132', 'unnamed:_133', 'unnamed:_134', 'unnamed:_135', 'unnamed:_136', 'unnamed:_137', 'unnamed:_138', 'unnamed:_139', 'unnamed:_140', 'unnamed:_141', 'unnamed:_142', 'unnamed:_143', 'unnamed:_144', 'unnamed:_145', 'unnamed:_146', 'unnamed:_147', 'unnamed:_148', 'unnamed:_149', 'unnamed:_150', 'unnamed:_151', 'unnamed:_152', 'unnamed:_153', 'unnamed:_154', 'unnamed:_155', 'unnamed:_156', 'unnamed:_157', 'unnamed:_158', 'unnamed:_159', 'unnamed:_160', 'unnamed:_161', 'unnamed:_162', 'unnamed:_163', 'unnamed:_164']

# %%
temp_df = pd.read_excel(files[0], header=None)
print(temp_df.head(15))
# Out:
#                                                   0    \
# 0                                            NEW YORK
# 1   Individual Income Tax Returns: \nSelected Inco...
# 2         [Money amounts are in thousands of dollars]
# 3                                       ZIP\ncode [1]
# 4                                                 NaN
# 5                                                 NaN
# 6                                                   0
# 7                                                   0
# 8                                                   0
# 9                                                   0
# 10                                                  0
# 11                                                  0
# 12                                                  0
# 13                                                NaN
# 14                                              10001
#
#                               1                      2    \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3   Size of adjusted gross income  Number of returns [2]
# 4                             NaN                    NaN
# 5                             NaN                     -1
# 6                           Total                9859080
# 7                $1 under $25,000                3140100
# 8           $25,000 under $50,000                2378060
# 9           $50,000 under $75,000                1421220
# 10         $75,000 under $100,000                 886130
# 11        $100,000 under $200,000                1394420
# 12               $200,000 or more                 639150
# 13                            NaN                    NaN
# 14                            NaN                  15590
#
#                          3                        4    \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3   Number of single returns  Number of joint returns
# 4                        NaN                      NaN
# 5                         -2                       -3
# 6                    5311490                  2857720
# 7                    2329450                   345820
# 8                    1358920                   425350
# 9                     754830                   372470
# 10                    372570                   364400
# 11                    382080                   859080
# 12                    113640                   490600
# 13                       NaN                      NaN
# 14                     11460                     2490
#
#                                     5    \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3   Number of head of household returns
# 4                                   NaN
# 5                                    -4
# 6                               1425040
# 7                                404460
# 8                                535030
# 9                                245760
# 10                               114260
# 11                               108910
# 12                                16620
# 13                                  NaN
# 14                                 1140
#
#                                        6    \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3   Number of electronically filed returns
# 4                                      NaN
# 5                                       -5
# 6                                  9324140
# 7                                  2907050
# 8                                  2271010
# 9                                  1354880
# 10                                  842700
# 11                                 1333070
# 12                                  615430
# 13                                     NaN
# 14                                   14740
#
#                                           7    \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3   Number of computer prepared paper returns
# 4                                         NaN
# 5                                          -6
# 6                                      172730
# 7                                       85380
# 8                                       40680
# 9                                       21580
# 10                                       9900
# 11                                      13820
# 12                                       1370
# 13                                        NaN
# 14                                        240
#
#                                       8    \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3   Number with paid preparer's signature
# 4                                     NaN
# 5                                      -7
# 6                                 6318550
# 7                                 1951260
# 8                                 1445860
# 9                                  888880
# 10                                 582070
# 11                                 959450
# 12                                 491030
# 13                                    NaN
# 14                                   8900
#
#                                       9    \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3   Number of returns with direct deposit
# 4                                     NaN
# 5                                      -8
# 6                                 6488130
# 7                                 2064570
# 8                                 1851650
# 9                                 1025960
# 10                                 585410
# 11                                 784410
# 12                                 176130
# 13                                    NaN
# 14                                   8640
#
#                                                   10   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Number of returns with virtual \ncurrency indi...
# 4                                                 NaN
# 5                                                  -9
# 6                                              138760
# 7                                               34590
# 8                                               29260
# 9                                               22070
# 10                                              11830
# 11                                              25750
# 12                                              15260
# 13                                                NaN
# 14                                                680
#
#                             11                                        12   \
# 0                           NaN                                       NaN
# 1                           NaN                                       NaN
# 2                           NaN                                       NaN
# 3   Number of \nindividuals [3]  Number of volunteer prepared returns [4]
# 4                           NaN                                     Total
# 5                           -10                                       -11
# 6                      17151570                                    105710
# 7                       4119270                                     64860
# 8                       4030750                                     32520
# 9                       2441570                                      7330
# 10                      1692280                                       940
# 11                      3164740                                        60
# 12                      1702960                                         0
# 13                          NaN                                       NaN
# 14                        20850                                       150
#
#                                                   13   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Number of volunteer income tax assistance (VIT...
# 5                                                 -12
# 6                                               82480
# 7                                               50870
# 8                                               26510
# 9                                                4720
# 10                                                360
# 11                                                 20
# 12                                                  0
# 13                                                NaN
# 14                                                150
#
#                                                   14   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Number of tax counseling for the elderly (TCE)...
# 5                                                 -13
# 6                                               23230
# 7                                               13990
# 8                                                6010
# 9                                                2610
# 10                                                580
# 11                                                 40
# 12                                                  0
# 13                                                NaN
# 14                                                  0
#
#                                                   15   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Number of volunteer prepared \nreturns with\ne...
# 5                                                 -14
# 6                                               16490
# 7                                               13780
# 8                                                2710
# 9                                                   0
# 10                                                  0
# 11                                                  0
# 12                                                  0
# 13                                                NaN
# 14                                                 50
#
#                                                 16   \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3   Number of refund anticipation check returns [5]
# 4                                               NaN
# 5                                               -15
# 6                                           1128230
# 7                                            403270
# 8                                            425430
# 9                                            169860
# 10                                            69940
# 11                                            57960
# 12                                             1770
# 13                                              NaN
# 14                                             1310
#
#                               17                               18   \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3   Number of elderly returns [6]  Adjusted gross income (AGI) [7]
# 4                             NaN                              NaN
# 5                             -16                              -17
# 6                         2433060                        896488301
# 7                          699310                         38138675
# 8                          472230                         86524324
# 9                          369930                         87395080
# 10                         273550                         76794361
# 11                         438460                        191316196
# 12                         179580                        416319665
# 13                            NaN                              NaN
# 14                           2780                          2799134
#
#                   19         20                         21         22   \
# 0                 NaN        NaN                        NaN        NaN
# 1                 NaN        NaN                        NaN        NaN
# 2                 NaN        NaN                        NaN        NaN
# 3        Total income        NaN  Salaries and wages in AGI        NaN
# 4   Number of returns     Amount          Number of returns     Amount
# 5                 -18        -19                        -20        -21
# 6             9859000  906554295                    7838620  565199580
# 7             3140020   38941182                    1973730   21625382
# 8             2378060   87518595                    2066790   64041023
# 9             1421220   88320059                    1240950   67595792
# 10             886130   77484325                     761690   57118529
# 11            1394420  193216491                    1225690  142338972
# 12             639150  421073643                     569770  212479882
# 13                NaN        NaN                        NaN        NaN
# 14              15590    2830868                      12670    1976619
#
#                   23        24                  25        26   \
# 0                 NaN       NaN                 NaN       NaN
# 1                 NaN       NaN                 NaN       NaN
# 2                 NaN       NaN                 NaN       NaN
# 3    Taxable interest       NaN  Ordinary dividends       NaN
# 4   Number of returns    Amount   Number of returns    Amount
# 5                 -22       -23                 -24       -25
# 6             3393360  10433351             2084660  23129127
# 7              557120    323975              303890    543621
# 8              487180    358663              266570    674839
# 9              496560    428862              280360    883891
# 10             428980    437885              247670    966616
# 11             889430   1231071              553150   3147118
# 12             534090   7652895              433020  16913042
# 13                NaN       NaN                 NaN       NaN
# 14               6680     34819                6190     65212
#
#                         27        28                                    29   \
# 0                       NaN       NaN                                   NaN
# 1                       NaN       NaN                                   NaN
# 2                       NaN       NaN                                   NaN
# 3   Qualified dividends [8]       NaN  State and local income tax refunds\n
# 4         Number of returns    Amount                     Number of returns
# 5                       -26       -27                                   -28
# 6                   1958190  17582015                                159600
# 7                    277750    355663                                  7930
# 8                    245900    458701                                 25210
# 9                    261210    623225                                 43590
# 10                   231700    705389                                 36690
# 11                   523770   2397729                                 40680
# 12                   417860  13041308                                  5500
# 13                      NaN       NaN                                   NaN
# 14                     5910     48108                                   240
#
#        30                                              31        32   \
# 0      NaN                                             NaN       NaN
# 1      NaN                                             NaN       NaN
# 2      NaN                                             NaN       NaN
# 3      NaN  Business or profession\nnet income (less loss)       NaN
# 4   Amount                               Number of returns    Amount
# 5      -29                                             -30       -31
# 6   183953                                         1662770  24841821
# 7     6525                                          675100   3804211
# 8    23672                                          316380   2641195
# 9    39700                                          178970   1732443
# 10   34897                                          119940   1406604
# 11   53865                                          231840   4263499
# 12   25294                                          140540  10993869
# 13     NaN                                             NaN       NaN
# 14     383                                            2850     72804
#
#                                     33        34   \
# 0                                   NaN       NaN
# 1                                   NaN       NaN
# 2                                   NaN       NaN
# 3   Net capital gain (less loss) in AGI       NaN
# 4                     Number of returns    Amount
# 5                                   -32       -33
# 6                               1892750  85031589
# 7                                280590    271088
# 8                                247280    565211
# 9                                248860    845995
# 10                               214030   1018391
# 11                               488010   4410312
# 12                               413980  77920592
# 13                                  NaN       NaN
# 14                                 5870    260006
#
#                                                   35        36   \
# 0                                                 NaN       NaN
# 1                                                 NaN       NaN
# 2                                                 NaN       NaN
# 3   Taxable individual retirement arrangements dis...       NaN
# 4                                   Number of returns    Amount
# 5                                                 -34       -35
# 6                                              708870  13900208
# 7                                              135190    839492
# 8                                              120800   1250789
# 9                                              111710   1553743
# 10                                              93010   1657064
# 11                                             174250   4575839
# 12                                              73910   4023281
# 13                                                NaN       NaN
# 14                                                900     20224
#
#                                37        38                        39   \
# 0                              NaN       NaN                       NaN
# 1                              NaN       NaN                       NaN
# 2                              NaN       NaN                       NaN
# 3   Taxable pensions and annuities       NaN  Number of \nfarm returns
# 4                Number of returns    Amount                       NaN
# 5                              -36       -37                       -38
# 6                          1767330  51536909                     18890
# 7                           358470   3283611                      5250
# 8                           322600   5471926                      5840
# 9                           295820   7301437                      4550
# 10                          238500   7839761                      1890
# 11                          415880  18789426                      1280
# 12                          136060   8850748                        80
# 13                             NaN       NaN                       NaN
# 14                            1680     49618                         0
#
#                               40        41                                42   \
# 0                             NaN       NaN                               NaN
# 1                             NaN       NaN                               NaN
# 2                             NaN       NaN                               NaN
# 3   Unemployment compensation [9]       NaN  Taxable Social Security benefits
# 4               Number of returns    Amount                 Number of returns
# 5                             -39       -40                               -41
# 6                         2402210  40508354                           1368840
# 7                          942910  14887679                            164860
# 8                          760470  13792633                            316530
# 9                          274670   4865707                            265150
# 10                         153890   2588813                            205730
# 11                         213510   3433794                            314590
# 12                          56760    939728                            101980
# 13                            NaN       NaN                               NaN
# 14                           3040     58928                              1360
#
#          43                                         44        45   \
# 0        NaN                                        NaN       NaN
# 1        NaN                                        NaN       NaN
# 2        NaN                                        NaN       NaN
# 3        NaN  Partnership/S-corp net income (less loss)       NaN
# 4     Amount                          Number of returns    Amount
# 5        -42                                        -43       -44
# 6   24516809                                     535060  53365397
# 7     386624                                      55360   -171527
# 8    2543901                                      62780    113689
# 9    4581151                                      57380    316859
# 10   4683868                                      47200    430932
# 11   8875433                                     130210   2616004
# 12   3445832                                     182130  50059440
# 13       NaN                                        NaN       NaN
# 14     24897                                       1500    268553
#
#                            46        47                 48      49   \
# 0                          NaN       NaN                NaN     NaN
# 1                          NaN       NaN                NaN     NaN
# 2                          NaN       NaN                NaN     NaN
# 3   Total statuory adjustments       NaN  Educator expenses     NaN
# 4            Number of returns    Amount  Number of returns  Amount
# 5                          -45       -46                -47     -48
# 6                      4191310  10065994             266860   70299
# 7                      1006180    802507               9900    2388
# 8                       855480    994271              34320    8413
# 9                       670130    924979              46070   11464
# 10                      455810    689964              37120    9448
# 11                      829790   1900295             102330   27998
# 12                      373920   4753978              37120   10588
# 13                         NaN       NaN                NaN     NaN
# 14                        6890     31734                180      44
#
#                                        50       51   \
# 0                                      NaN      NaN
# 1                                      NaN      NaN
# 2                                      NaN      NaN
# 3   Self-employed (Keogh) retirement plans      NaN
# 4                        Number of returns   Amount
# 5                                      -49      -50
# 6                                    74910  2434325
# 7                                      720     6458
# 8                                     3200    33310
# 9                                     4570    56514
# 10                                    2790    42439
# 11                                   18830   347289
# 12                                   44800  1948315
# 13                                     NaN      NaN
# 14                                     300    10819
#
#                                          52       53   \
# 0                                        NaN      NaN
# 1                                        NaN      NaN
# 2                                        NaN      NaN
# 3   Self-employed health insurance deduction      NaN
# 4                          Number of returns   Amount
# 5                                        -51      -52
# 6                                     156240  1659233
# 7                                      15080    61374
# 8                                      23590   119334
# 9                                      20570   139015
# 10                                     11940    92833
# 11                                     35350   350102
# 12                                     49710   896575
# 13                                       NaN      NaN
# 14                                       580     5382
#
#                                            54      55   \
# 0                                          NaN     NaN
# 1                                          NaN     NaN
# 2                                          NaN     NaN
# 3   Individual retirement arrangement payments     NaN
# 4                            Number of returns  Amount
# 5                                          -53     -54
# 6                                       165410  929880
# 7                                        13600   56438
# 8                                        43780  197454
# 9                                        38760  197098
# 10                                       18750  117608
# 11                                       42580  284741
# 12                                        7940   76541
# 13                                         NaN     NaN
# 14                                         320    1780
#
#                                 56      57   \
# 0                               NaN     NaN
# 1                               NaN     NaN
# 2                               NaN     NaN
# 3   Student loan interest deduction     NaN
# 4                 Number of returns  Amount
# 5                               -55     -56
# 6                            606180  490482
# 7                             70770   58487
# 8                            180660  144966
# 9                            170190  144008
# 10                            75450   49933
# 11                           109110   93088
# 12                                0       0
# 13                              NaN     NaN
# 14                              690     564
#
#                                                   58      59   \
# 0                                                 NaN     NaN
# 1                                                 NaN     NaN
# 2                                                 NaN     NaN
# 3   Charitable contributions \nif took standard de...     NaN
# 4                                   Number of returns  Amount
# 5                                                 -57     -58
# 6                                             2557960  673823
# 7                                              400060   97000
# 8                                              509120  130399
# 9                                              442710  116042
# 10                                             333990   89196
# 11                                             628230  172246
# 12                                             243850   68940
# 13                                                NaN     NaN
# 14                                               4500    1118
#
#                          60         61                        62         63   \
# 0                        NaN        NaN                       NaN        NaN
# 1                        NaN        NaN                       NaN        NaN
# 2                        NaN        NaN                       NaN        NaN
# 3   Total standard deduction        NaN  Basic standard deduction        NaN
# 4          Number of returns     Amount         Number of returns     Amount
# 5                        -59        -60                       -61        -62
# 6                    8833830  148828348                   8833700  145933827
# 7                    3087760   43595862                   3087750   42666657
# 8                    2288620   37252568                   2288610   36704136
# 9                    1285910   22157622                   1285900   21736593
# 10                    742700   14340275                    742680   14015839
# 11                   1075700   23396768                   1075640   22882054
# 12                    353140    8085253                    353120    7928548
# 13                       NaN        NaN                       NaN        NaN
# 14                     13640     201195                     13640     198261
#
#                               64       65                         66   \
# 0                             NaN      NaN                        NaN
# 1                             NaN      NaN                        NaN
# 2                             NaN      NaN                        NaN
# 3   Additional standard deduction      NaN  Total itemized deductions
# 4               Number of returns   Amount          Number of returns
# 5                             -63      -64                        -65
# 6                         1501140  2886416                    1017030
# 7                          509180   929491                      49550
# 8                          291650   549908                      88850
# 9                          223120   422976                     137020
# 10                         162630   322900                     142010
# 11                         244880   513043                     318530
# 12                          69680   148098                     281070
# 13                            NaN      NaN                        NaN
# 14                           1630     2933                       1960
#
#          67             68                                             69   \
# 0        NaN            NaN                                            NaN
# 1        NaN            NaN                                            NaN
# 2        NaN            NaN                                            NaN
# 3        NaN            NaN  Total medical and dental \nexpenses deduction
# 4     Amount  Amount of AGI                              Number of returns
# 5        -66            -67                                            -68
# 6   39995580      343771137                                         191280
# 7    1086407         749836                                          29710
# 8    2106762        3447105                                          38000
# 9    3268205        8746933                                          39740
# 10   3511793       12597020                                          28490
# 11   9114151       45441897                                          45830
# 12  20908262      272788346                                           9510
# 13       NaN            NaN                                            NaN
# 14     91961        1141002                                            450
#
#         70                            71        72   \
# 0       NaN                           NaN       NaN
# 1       NaN                           NaN       NaN
# 2       NaN                           NaN       NaN
# 3       NaN  State and local income taxes       NaN
# 4    Amount             Number of returns    Amount
# 5       -69                           -70       -71
# 6   3407881                        843750  28065398
# 7    411333                         15950     41530
# 8    572798                         58160    162432
# 9    619280                        109160    454860
# 10   474730                        118670    704606
# 11   934322                        280120   2825865
# 12   395418                        261690  23876105
# 13      NaN                           NaN       NaN
# 14    11553                          1720    133748
#
#                                     73      74                 75        76   \
# 0                                   NaN     NaN                NaN       NaN
# 1                                   NaN     NaN                NaN       NaN
# 2                                   NaN     NaN                NaN       NaN
# 3   State and local general sales taxes     NaN  Real estate taxes       NaN
# 4                     Number of returns  Amount  Number of returns    Amount
# 5                                   -72     -73                -74       -75
# 6                                148170  174366             867690  10411610
# 7                                 25480   16265              33510    293463
# 8                                 27250   25449              68370    559205
# 9                                 25700   28816             115040    879522
# 10                                19350   24670             122260    957834
# 11                                35230   50780             277150   2662343
# 12                                15160   28386             251360   5059243
# 13                                  NaN     NaN                NaN       NaN
# 14                                  210     224               1290     20824
#
#                         77      78                                  79   \
# 0                       NaN     NaN                                 NaN
# 1                       NaN     NaN                                 NaN
# 2                       NaN     NaN                                 NaN
# 3   Personal property taxes     NaN  Limited state and local taxes paid
# 4         Number of returns  Amount                   Number of returns
# 5                       -76     -77                                 -78
# 6                     44350   61998                             1000550
# 7                       470     590                               46690
# 8                      4050    6906                               85690
# 9                      9800   14319                              134510
# 10                     5750    7376                              139680
# 11                    15930   20135                              314650
# 12                     8350   12672                              279330
# 13                      NaN     NaN                                 NaN
# 14                       70      27                                1920
#
#         80                 81       82                            83   \
# 0       NaN                NaN      NaN                           NaN
# 1       NaN                NaN      NaN                           NaN
# 2       NaN                NaN      NaN                           NaN
# 3       NaN   Total taxes paid      NaN  Home mortgage interest paid
# 4    Amount  Number of returns   Amount             Number of returns
# 5       -79                -80      -81                           -82
# 6   9029008            1013350  9305513                        785510
# 7    281615              47780   292378                         24680
# 8    597069              87830   639116                         56840
# 9   1085041             136640  1116619                        102330
# 10  1249088             141810  1267886                        109760
# 11  3037109             318340  3078616                        258500
# 12  2779086             280950  2910898                        233400
# 13      NaN                NaN      NaN                           NaN
# 14    17216               1950    17626                          1230
#
#          84                                                85      86   \
# 0        NaN                                               NaN     NaN
# 1        NaN                                               NaN     NaN
# 2        NaN                                               NaN     NaN
# 3        NaN  Home mortgage interest paid \nto personal seller     NaN
# 4     Amount                                 Number of returns  Amount
# 5        -83                                               -84     -85
# 6   10188494                                             13200  129900
# 7     243935                                               100     651
# 8     560241                                               870    6419
# 9     944688                                              1890   13689
# 10   1059821                                              1630   13016
# 11   3118747                                              4810   37549
# 12   4261062                                              3900   58576
# 13       NaN                                               NaN     NaN
# 14     18801                                                60    1035
#
#                   87      88                                     89      90   \
# 0                 NaN     NaN                                    NaN     NaN
# 1                 NaN     NaN                                    NaN     NaN
# 2                 NaN     NaN                                    NaN     NaN
# 3   Deductible points     NaN  Qualified mortgage insurance premiums     NaN
# 4   Number of returns  Amount                      Number of returns  Amount
# 5                 -86     -87                                    -88     -89
# 6               26770   30404                                  55200  121688
# 7                 230     162                                   1050    2721
# 8                 810     943                                   8980   22419
# 9                2700    3872                                  21760   47156
# 10               2110    2927                                  20490   45244
# 11              12000   14991                                   2920    4148
# 12               8920    7509                                      0       0
# 13                NaN     NaN                                    NaN     NaN
# 14                 30      16                                    100      37
#
#                          91       92                              93   \
# 0                        NaN      NaN                             NaN
# 1                        NaN      NaN                             NaN
# 2                        NaN      NaN                             NaN
# 3   Investment interest paid      NaN  Total charitable contributions
# 4          Number of returns   Amount               Number of returns
# 5                        -90      -91                             -92
# 6                      59880  1483328                          846410
# 7                        720      822                           27100
# 8                       1240     2151                           61740
# 9                       2100     4106                          104560
# 10                      1470     4063                          113550
# 11                      9400    36889                          279070
# 12                     44950  1435297                          260390
# 13                       NaN      NaN                             NaN
# 14                       280     4723                            1620
#
#          94                                         95      96   \
# 0        NaN                                        NaN     NaN
# 1        NaN                                        NaN     NaN
# 2        NaN                                        NaN     NaN
# 3        NaN  Other non-limited miscellaneous deduction     NaN
# 4     Amount                          Number of returns  Amount
# 5        -93                                        -94     -95
# 6   13051755                                      38010  500702
# 7      57283                                        720    7922
# 8     210249                                       2640   29902
# 9     414690                                       5660   64315
# 10    502206                                       2940   35494
# 11   1633427                                      10940  160517
# 12  10233900                                      15110  202552
# 13       NaN                                        NaN     NaN
# 14     29056                                        110     978
#
#                                       97       98                 99   \
# 0                                     NaN      NaN                NaN
# 1                                     NaN      NaN                NaN
# 2                                     NaN      NaN                NaN
# 3   Qualified business income deduction\n      NaN     Taxable income
# 4                       Number of returns   Amount  Number of returns
# 5                                     -96      -97                -98
# 6                                 1364580  8056414            7914160
# 7                                  146320    94189            1221070
# 8                                  262960   380162            2357830
# 9                                  186820   392968            1418470
# 10                                 145690   368830             884840
# 11                                 333170  1314642            1393170
# 12                                 289620  5505623             638780
# 13                                    NaN      NaN                NaN
# 14                                   3610    20782              13330
#
#           100                        101        102                      103  \
# 0         NaN                        NaN        NaN                      NaN
# 1         NaN                        NaN        NaN                      NaN
# 2         NaN                        NaN        NaN                      NaN
# 3         NaN  Income tax before credits        NaN  Alternative minimum tax
# 4      Amount          Number of returns     Amount        Number of returns
# 5         -99                       -100       -101                     -102
# 6   711933881                    7860000  146540343                     6920
# 7     6812030                    1190740     685799                        0
# 8    46955069                    2340830    5070717                        0
# 9    61699248                    1414830    7570834                        0
# 10   58571256                     883200    8049762                        0
# 11  157512098                    1391880   24972309                      290
# 12  380384180                     638520  100190922                     6630
# 13        NaN                        NaN        NaN                      NaN
# 14    2511607                      13200     649244                       50
#
#        104                                            105     106  \
# 0      NaN                                            NaN     NaN
# 1      NaN                                            NaN     NaN
# 2      NaN                                            NaN     NaN
# 3      NaN  Excess advance \npremium tax credit repayment     NaN
# 4   Amount                              Number of returns  Amount
# 5     -103                                           -104    -105
# 6   127494                                          21260   20830
# 7        0                                            250     166
# 8        0                                          15460   11244
# 9        0                                           5370    8834
# 10       0                                            180     586
# 11    3154                                              0       0
# 12  124340                                              0       0
# 13     NaN                                            NaN     NaN
# 14    1134                                             40      42
#
#                        107      108                 109      110  \
# 0                      NaN      NaN                 NaN      NaN
# 1                      NaN      NaN                 NaN      NaN
# 2                      NaN      NaN                 NaN      NaN
# 3   Total tax credits [10]      NaN  Foreign tax credit      NaN
# 4        Number of returns   Amount   Number of returns   Amount
# 5                     -106     -107                -108     -109
# 6                  3339440  7438980              616620  1583147
# 7                   378260   141469               17500      909
# 8                  1015150  1161764               56080     4543
# 9                   522610  1026533               75020     8467
# 10                  340100   771842               68860     9963
# 11                  683880  1721978              181940    50921
# 12                  399440  2615394              217220  1508344
# 13                     NaN      NaN                 NaN      NaN
# 14                    4640    22119                2810    18505
#
#                                 111     112                             113  \
# 0                               NaN     NaN                             NaN
# 1                               NaN     NaN                             NaN
# 2                               NaN     NaN                             NaN
# 3   Child and dependent care credit     NaN  Nonrefundable education credit
# 4                 Number of returns  Amount               Number of returns
# 5                              -110    -111                            -112
# 6                            297320  173946                          451280
# 7                              7360    2564                           87910
# 8                             73930   43637                          162390
# 9                             48660   28696                           80400
# 10                            29100   17300                           44580
# 11                            83520   49247                           76000
# 12                            54750   32502                               0
# 13                              NaN     NaN                             NaN
# 14                              260     141                             460
#
# ...
# 4                  Number of returns   Amount              Number of returns
# 5                               -116     -117                           -118
# 6                            2225470  4441865                          99160
# 7                             171830    66814                            740
# 8                             697850   868673                          14880
# 9                             387690   851753                          21640
# 10                            256860   650224                          15010
# 11                            510830  1408683                          36370
# 12                            200410   595718                          10520
# 13                               NaN      NaN                            NaN
# 14                              1340     2169                             20
#
#        120                  121      122                       123     124  \
# 0      NaN                  NaN      NaN                       NaN     NaN
# 1      NaN                  NaN      NaN                       NaN     NaN
# 2      NaN                  NaN      NaN                       NaN     NaN
# 3      NaN  Self-employment tax      NaN  Total premium tax credit     NaN
# 4   Amount    Number of returns   Amount         Number of returns  Amount
# 5     -119                 -120     -121                      -122    -123
# 6   118561              1300960  4559076                     66740  291062
# 7      280               570680   632485                     14950   69661
# 8     8868               229560   489495                     45510  186090
# 9    18401               119930   336653                      6210   34964
# 10   15777                80810   273763                        70     347
# 11   51421               162700   761193                         0       0
# 12   23814               137280  2065487                         0       0
# 13     NaN                  NaN      NaN                       NaN     NaN
# 14      96                 2240    14642                       120     511
#
#                            125     126                 127        128  \
# 0                          NaN     NaN                 NaN        NaN
# 1                          NaN     NaN                 NaN        NaN
# 2                          NaN     NaN                 NaN        NaN
# 3   Advance premium tax credit     NaN  Total tax payments        NaN
# 4            Number of returns  Amount   Number of returns     Amount
# 5                         -124    -125                -126       -127
# 6                        74080  281990             9259410  165326471
# 7                        14600   54694             2641110    6415088
# 8                        45960  168437             2319440    9851022
# 9                        12120   52921             1402140    9569317
# 10                        1400    5938              878130    9197897
# 11                           0       0             1384320   26153001
# 12                           0       0              634270  104140146
# 13                         NaN     NaN                 NaN        NaN
# 14                         130     483               14610     645108
#
#                           129      130  \
# 0                         NaN      NaN
# 1                         NaN      NaN
# 2                         NaN      NaN
# 3   Earned income credit [11]      NaN
# 4           Number of returns   Amount
# 5                        -128     -129
# 6                     1507680  3222686
# 7                      963900  1976563
# 8                      534200  1240757
# 9                        9580     5366
# 10                          0        0
# 11                          0        0
# 12                          0        0
# 13                        NaN      NaN
# 14                       1390     2097
#
#                                                 131      132  \
# 0                                               NaN      NaN
# 1                                               NaN      NaN
# 2                                               NaN      NaN
# 3   Excess earned income credit \n(refundable) [12]      NaN
# 4                                 Number of returns   Amount
# 5                                              -130     -131
# 6                                           1275840  2827565
# 7                                            786860  1736243
# 8                                            482410  1087736
# 9                                              6570     3586
# 10                                                0        0
# 11                                                0        0
# 12                                                0        0
# 13                                              NaN      NaN
# 14                                             1100     1823
#
#                             133      134                               135  \
# 0                           NaN      NaN                               NaN
# 1                           NaN      NaN                               NaN
# 2                           NaN      NaN                               NaN
# 3   Additional child tax credit      NaN  Refundable education credit [13]
# 4             Number of returns   Amount                 Number of returns
# 5                          -132     -133                              -134
# 6                       1018010  1690326                            379610
# 7                        439550   665803                            125000
# 8                        484340   855516                            101270
# 9                         84290   145689                             55060
# 10                         8210    17822                             32300
# 11                         1620     5496                             65980
# 12                            0        0                                 0
# 13                          NaN      NaN                               NaN
# 14                          600      870                               330
#
#        136                     137     138  \
# 0      NaN                     NaN     NaN
# 1      NaN                     NaN     NaN
# 2      NaN                     NaN     NaN
# 3      NaN  Net premium tax credit     NaN
# 4   Amount       Number of returns  Amount
# 5     -135                    -136    -137
# 6   336741                   35080   40463
# 7   107458                   10900   13797
# 8    86945                   23170   25247
# 9    50186                    1010    1419
# 10   28659                       0       0
# 11   63493                       0       0
# 12       0                       0       0
# 13     NaN                     NaN     NaN
# 14     278                      80      99
#
#                                        139     140  \
# 0                                      NaN     NaN
# 1                                      NaN     NaN
# 2                                      NaN     NaN
# 3   Qualified sick and family leave credit     NaN
# 4                        Number of returns  Amount
# 5                                     -138    -139
# 6                                    36150   62792
# 7                                    19500   19539
# 8                                     9130   15025
# 9                                     2830    6809
# 10                                     930    3111
# 11                                    2390    9953
# 12                                    1370    8355
# 13                                     NaN     NaN
# 14                                      70     160
#
#                             141      142  \
# 0                           NaN      NaN
# 1                           NaN      NaN
# 2                           NaN      NaN
# 3   Recovery rebate credit [14]      NaN
# 4             Number of returns   Amount
# 5                          -140     -141
# 6                       1598690  2252071
# 7                        681680  1058983
# 8                        326760   460999
# 9                        201790   255383
# 10                       165570   156136
# 11                       221420   319944
# 12                         1470      626
# 13                          NaN      NaN
# 14                         2370     3084
#
#                                               143       144  \
# 0                                             NaN       NaN
# 1                                             NaN       NaN
# 2                                             NaN       NaN
# 3   Economic impact payment\nfirst round [15, 16]       NaN
# 4                               Number of returns    Amount
# 5                                            -142      -143
# 6                                         7376930  12579804
# 7                                         2044100   3151656
# 8                                         2099160   3443445
# 9                                         1298740   2196219
# 10                                         787850   1427975
# 11                                        1016010   2163026
# 12                                         131070    197483
# 13                                            NaN       NaN
# 14                                           9150     12573
#
#                                                145      146  \
# 0                                              NaN      NaN
# 1                                              NaN      NaN
# 2                                              NaN      NaN
# 3   Economic impact payment\nsecond round [15, 17]      NaN
# 4                                Number of returns   Amount
# 5                                             -144     -145
# 6                                          6720340  6695667
# 7                                          1873550  1638262
# 8                                          2013130  1940000
# 9                                          1238680  1192234
# 10                                          687240   746664
# 11                                          845220  1115216
# 12                                           62520    63291
# 13                                             NaN      NaN
# 14                                            7740     5887
#
#                          147        148                       149        150  \
# 0                        NaN        NaN                       NaN        NaN
# 1                        NaN        NaN                       NaN        NaN
# 2                        NaN        NaN                       NaN        NaN
# 3   Income tax after credits        NaN  Total tax liability [18]        NaN
# 4          Number of returns     Amount         Number of returns     Amount
# 5                       -146       -147                      -148       -149
# 6                    6928830  138986860                   7549320  148836268
# 7                     909910     543166                   1392250    1184695
# 8                    1802270    3910708                   1909610    4423864
# 9                    1324660    6548642                   1346830    6912696
# 10                    868150    7272995                    873260    7581941
# 11                   1386120   23247584                   1388650   24094452
# 12                    637720   97463765                    638720  104638620
# 13                       NaN        NaN                       NaN        NaN
# 14                     12540     627125                     13170     661677
#
#                               151      152                        153  \
# 0                             NaN      NaN                        NaN
# 1                             NaN      NaN                        NaN
# 2                             NaN      NaN                        NaN
# 3   Total additional Medicare tax      NaN  Net investment income tax
# 4               Number of returns   Amount          Number of returns
# 5                            -150     -151                       -152
# 6                          402360  1140788                     412560
# 7                               0        0                          0
# 8                               0        0                          0
# 9                               0        0                          0
# 10                              0        0                          0
# 11                          31070     7320                       8790
# 12                         371290  1133468                     403770
# 13                            NaN      NaN                        NaN
# 14                           2630     8203                       2360
#
#         154                             155       156                 157  \
# 0       NaN                             NaN       NaN                 NaN
# 1       NaN                             NaN       NaN                 NaN
# 2       NaN                             NaN       NaN                 NaN
# 3       NaN  Tax due at time of filing [19]       NaN  Total overpayments
# 4    Amount               Number of returns    Amount   Number of returns
# 5      -153                            -154      -155                -156
# 6   3426319                         2060720  13587489             7462950
# 7         0                          414790    325455             2417690
# 8         0                          321350    456316             2044550
# 9         0                          281770    557136             1139120
# 10        0                          220530    578835              660480
# 11     1938                          482090   2054647              910870
# 12  3424381                          340190   9615100              290240
# 13      NaN                             NaN       NaN                 NaN
# 14    10333                            4820     77063               10170
#
#          158                         159       160  \
# 0        NaN                         NaN       NaN
# 1        NaN                         NaN       NaN
# 2        NaN                         NaN       NaN
# 3        NaN  Overpayments refunded [20]       NaN
# 4     Amount           Number of returns    Amount
# 5       -157                        -158      -159
# 6   30467165                     7237940  22383707
# 7    5552725                     2400360   5485348
# 8    5879639                     2026370   5786997
# 9    3206779                     1117680   3088720
# 10   2191953                      639770   2059618
# 11   4095003                      855740   3551825
# 12   9541066                      198020   2411199
# 13       NaN                         NaN       NaN
# 14     60052                        9430     33592
#
#                                       161      162
# 0                                     NaN      NaN
# 1                                     NaN      NaN
# 2                                     NaN      NaN
# 3   Credited to next year's estimated tax      NaN
# 4                       Number of returns   Amount
# 5                                    -160     -161
# 6                                  276950  7883265
# 7                                   21010    52286
# 8                                   25930    83866
# 9                                   32070   119219
# 10                                  24840   117194
# 11                                  72630   550420
# 12                                 100470  6960280
# 13                                    NaN      NaN
# 14                                    880    26461

# %%
df = pd.read_excel(file, header=[3,4])

# %%
# Drop rows with too many missing values
df = df.dropna(thresh=int(0.6 * len(df.columns)))

# Fill numeric missing values with 0
numeric_cols = df.select_dtypes(include=np.number).columns
df[numeric_cols] = df[numeric_cols].fillna(0)

# Ensure ZIP codes stay 5-digit
if "zipcode" in df.columns:
    df["zipcode"] = df["zipcode"].astype(str).str.zfill(5)

# Convert Year column to integer
df["year"] = pd.to_numeric(df["year"], errors="coerce")
df = df.dropna(subset=["year"])   # Remove rows where year couldn't be extracted
df["year"] = df["year"].astype(int)


print("\nCleaned Dataset Shape:", df.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/erdos_ds_environment/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 13
#      10     df["zipcode"] = df["zipcode"].astype(str).str.zfill(5)
#      12 # Convert Year column to integer
# ---> 13 df["year"] = pd.to_numeric(df["year"], errors="coerce")
#      14 df = df.dropna(subset=["year"])   # Remove rows where year couldn't be extracted
#      15 df["year"] = df["year"].astype(int)
#
# File /opt/anaconda3/envs/erdos_ds_environment/lib/python3.12/site-packages/pandas/core/frame.py:4377, in DataFrame.__getitem__(self, key)
#    4375 if is_single_key:
#    4376     if self.columns.nlevels > 1:
# -> 4377         return self._getitem_multilevel(key)
#    4378     indexer = self.columns.get_loc(key)
#    4379     if is_integer(indexer):
#
# File /opt/anaconda3/envs/erdos_ds_environment/lib/python3.12/site-packages/pandas/core/frame.py:4435, in DataFrame._getitem_multilevel(self, key)
#    4433 def _getitem_multilevel(self, key):
#    4434     # self.columns is a MultiIndex
# -> 4435     loc = self.columns.get_loc(key)
#    4436     if isinstance(loc, (slice, np.ndarray)):
#    4437         new_columns = self.columns[loc]
#
# File /opt/anaconda3/envs/erdos_ds_environment/lib/python3.12/site-packages/pandas/core/indexes/multi.py:3523, in MultiIndex.get_loc(self, key)
#    3520     return mask
#    3522 if not isinstance(key, tuple):
# -> 3523     loc = self._get_level_indexer(key, level=0)
#    3524     return _maybe_to_slice(loc)
#    3526 keylen = len(key)
#
# File /opt/anaconda3/envs/erdos_ds_environment/lib/python3.12/site-packages/pandas/core/indexes/multi.py:3885, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3882         return slice(i, j, step)
#    3884 else:
# -> 3885     idx = self._get_loc_single_level_index(level_index, key)
#    3887     if level > 0 or self._lexsort_depth == 0:
#    3888         # Desired level is not sorted
#    3889         if isinstance(idx, slice):
#    3890             # test_get_loc_partial_timestamp_multiindex
#
# File /opt/anaconda3/envs/erdos_ds_environment/lib/python3.12/site-packages/pandas/core/indexes/multi.py:3458, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    3456     return -1
#    3457 else:
# -> 3458     return level_index.get_loc(key)
#
# File /opt/anaconda3/envs/erdos_ds_environment/lib/python3.12/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'year'

# %%
4. #EXPLORATORY DATA ANALYSIS
# ============================================

print("\nSummary Statistics:")
print(df.describe())

print("\nData Info:")
print(df.info())

# %%
# 5. VISUALIZATIONS
# ============================================

# Example: Total AGI trend over time
if "adjusted_gross_income" in df.columns:
    yearly_agi = df.groupby("year")["adjusted_gross_income"].sum()
    
    plt.figure(figsize=(8,5))
    yearly_agi.plot(marker="o")
    plt.title("Total Adjusted Gross Income by Year")
    plt.xlabel("Year")
    plt.ylabel("Total AGI")
    plt.show()

# Correlation heatmap
plt.figure(figsize=(10,8))
corr = df.select_dtypes(include=np.number).corr()
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.show()
